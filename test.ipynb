# %%
# !python OWL2Vec_Standalone.py --config_file default.cfg
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
#
# Warning: SQLite3 version 3.40.0 and 3.41.2 have huge performance regressions; please install version 3.41.1 or 3.42!
#
#
#  Access the ontology ...
# INFO: There are 17076 triples in the ontology
#
# Calculate the ontology projection ...
# INFO: Creating ontology graph projection...
# INFO: 	Extracting subsumption triples
# INFO: 		Time extracting subsumption: 0.26934123039245605 seconds
# INFO: 	Extracting equivalence triples
# INFO: 		Time extracting equivalences: 0.01678609848022461 seconds
# INFO: 	Extracting class membership triples.
# INFO: 		Time extracting class membership: 0.9929442405700684 seconds
# INFO: 	Extracting sameAs triples
# INFO: 		Time extracting sameAs: 0.0071032047271728516 seconds
# INFO: 	Extracting triples associated to hasSpecificationVersion
# INFO: 		Time extracting triples for property: 0.13025474548339844 seconds
# INFO: 	Extracting triples associated to isVersionOf
# INFO: 		Time extracting triples for property: 0.14336395263671875 seconds
# INFO: 	Extracting triples associated to isReflectedIn
# INFO: 		Time extracting triples for property: 0.12595748901367188 seconds
# INFO: 	Extracting triples associated to reflects
# INFO: 		Time extracting triples for property: 0.1232762336730957 seconds
# INFO: 	Extracting triples associated to broadMatch
# INFO: 		Time extracting triples for property: 0.10603213310241699 seconds
# INFO: 	Extracting triples associated to broader
# INFO: 		Time extracting triples for property: 0.10941720008850098 seconds
# INFO: 	Extracting triples associated to mappingRelation
# INFO: 		Time extracting triples for property: 0.12884306907653809 seconds
# INFO: 	Extracting triples associated to narrowMatch
# INFO: 		Time extracting triples for property: 0.18526220321655273 seconds
# INFO: 	Extracting triples associated to broaderTransitive
# INFO: 		Time extracting triples for property: 0.10976862907409668 seconds
# INFO: 	Extracting triples associated to narrower
# INFO: 		Time extracting triples for property: 0.11377882957458496 seconds
# INFO: 	Extracting triples associated to semanticRelation
# INFO: 		Time extracting triples for property: 0.14233922958374023 seconds
# INFO: 	Extracting triples associated to narrowerTransitive
# INFO: 		Time extracting triples for property: 0.12394452095031738 seconds
# INFO: 	Extracting triples associated to closeMatch
# INFO: 		Time extracting triples for property: 0.11893486976623535 seconds
# INFO: 	Extracting triples associated to exactMatch
# INFO: 		Time extracting triples for property: 0.1205759048461914 seconds
# INFO: 	Extracting triples associated to hasTopConcept
# INFO: 		Time extracting triples for property: 0.13106584548950195 seconds
# INFO: 	Extracting triples associated to topConceptOf
# INFO: 		Time extracting triples for property: 0.13022589683532715 seconds
# INFO: 	Extracting triples associated to inScheme
# INFO: 		Time extracting triples for property: 0.11418914794921875 seconds
# INFO: 	Extracting triples associated to member
# INFO: 		Time extracting triples for property: 0.14320826530456543 seconds
# INFO: 	Extracting triples associated to memberList
# INFO: 		Time extracting triples for property: 0.12400603294372559 seconds
# INFO: 	Extracting triples associated to related
# INFO: 		Time extracting triples for property: 0.1052093505859375 seconds
# INFO: 	Extracting triples associated to relatedMatch
# INFO: 		Time extracting triples for property: 0.11067843437194824 seconds
# INFO: 	Extracting triples associated to hasDateOfIncorporation
# INFO: 		Time extracting triples for property: 0.12334060668945312 seconds
# INFO: 	Extracting triples associated to hasExplicitDate
# INFO: 		Time extracting triples for property: 0.11329174041748047 seconds
# INFO: 	Extracting triples associated to hasDateOfRegistration
# INFO: 		Time extracting triples for property: 0.11710762977600098 seconds
# INFO: 	Extracting triples associated to hasIssuedCapital
# INFO: 		Time extracting triples for property: 0.11885356903076172 seconds
# INFO: 	Extracting triples associated to hasMonetaryAmount
# INFO: 		Time extracting triples for property: 0.17241859436035156 seconds
# INFO: 	Extracting triples associated to isConstitutedBy
# INFO: 		Time extracting triples for property: 0.14066433906555176 seconds
# INFO: 	Extracting triples associated to isIncorporatedIn
# INFO: 		Time extracting triples for property: 0.1425936222076416 seconds
# INFO: 	Extracting triples associated to isOrganizedIn
# INFO: 		Time extracting triples for property: 0.14013457298278809 seconds
# INFO: 	Extracting triples associated to hasEquity
# INFO: 		Time extracting triples for property: 0.12330126762390137 seconds
# INFO: 	Extracting triples associated to has
# INFO: 		Time extracting triples for property: 0.14859294891357422 seconds
# INFO: 	Extracting triples associated to hasHeadquartersAddress
# INFO: 		Time extracting triples for property: 0.11421561241149902 seconds
# INFO: 	Extracting triples associated to hasOperatingAddress
# INFO: 		Time extracting triples for property: 0.1307234764099121 seconds
# INFO: 	Extracting triples associated to hasAddress
# INFO: 		Time extracting triples for property: 0.12869620323181152 seconds
# INFO: 	Extracting triples associated to hasRegisteredAddress
# INFO: 		Time extracting triples for property: 0.122039794921875 seconds
# INFO: 	Extracting triples associated to isRecognizedIn
# INFO: 		Time extracting triples for property: 0.1773078441619873 seconds
# INFO: 	Extracting triples associated to hasBaseCurrency
# INFO: 		Time extracting triples for property: 0.13101744651794434 seconds
# INFO: 	Extracting triples associated to hasCurrency
# INFO: 		Time extracting triples for property: 0.17826247215270996 seconds
# INFO: 	Extracting triples associated to hasMeasurementUnit
# INFO: 		Time extracting triples for property: 0.16551589965820312 seconds
# INFO: 	Extracting triples associated to hasDealtCurrency
# INFO: 		Time extracting triples for property: 0.12798571586608887 seconds
# INFO: 	Extracting triples associated to hasNotionalAmount
# INFO: 		Time extracting triples for property: 0.12890338897705078 seconds
# INFO: 	Extracting triples associated to hasPrice
# INFO: 		Time extracting triples for property: 0.11136317253112793 seconds
# INFO: 	Extracting triples associated to isPriceFor
# INFO: 		Time extracting triples for property: 0.13278913497924805 seconds
# INFO: 	Extracting triples associated to refersTo
# INFO: 		Time extracting triples for property: 0.20161056518554688 seconds
# INFO: 	Extracting triples associated to isTenderIn
# INFO: 		Time extracting triples for property: 0.1062619686126709 seconds
# INFO: 	Extracting triples associated to isUsedBy
# INFO: 		Time extracting triples for property: 0.1385793685913086 seconds
# INFO: 	Extracting triples associated to hasStructuredName
# INFO: 		Time extracting triples for property: 0.1635439395904541 seconds
# INFO: 	Extracting triples associated to isStructuredNameOf
# INFO: 		Time extracting triples for property: 0.17127776145935059 seconds
# INFO: 	Extracting triples associated to hasAgeOfMajority
# INFO: 		Time extracting triples for property: 0.12873125076293945 seconds
# INFO: 	Extracting triples associated to hasAge
# INFO: 		Time extracting triples for property: 0.13248038291931152 seconds
# INFO: 	Extracting triples associated to hasCitizenship
# INFO: 		Time extracting triples for property: 0.1434948444366455 seconds
# INFO: 	Extracting triples associated to hasDateOfBirth
# INFO: 		Time extracting triples for property: 0.1401529312133789 seconds
# INFO: 	Extracting triples associated to hasDateOfDeath
# INFO: 		Time extracting triples for property: 0.1387650966644287 seconds
# INFO: 	Extracting triples associated to hasMinimumLegalWorkingAge
# INFO: 		Time extracting triples for property: 0.12895870208740234 seconds
# INFO: 	Extracting triples associated to hasPlaceOfBirth
# INFO: 		Time extracting triples for property: 0.14348125457763672 seconds
# INFO: 	Extracting triples associated to hasPrimaryResidence
# INFO: 		Time extracting triples for property: 0.14737677574157715 seconds
# INFO: 	Extracting triples associated to hasResidence
# INFO: 		Time extracting triples for property: 0.1410079002380371 seconds
# INFO: 	Extracting triples associated to hasObligation
# INFO: 		Time extracting triples for property: 0.1341400146484375 seconds
# INFO: 	Extracting triples associated to isObligationOf
# INFO: 		Time extracting triples for property: 0.1290132999420166 seconds
# INFO: 	Extracting triples associated to definesTermsFor
# INFO: 		Time extracting triples for property: 0.11583924293518066 seconds
# INFO: 	Extracting triples associated to hasContractDuration
# INFO: 		Time extracting triples for property: 0.18604421615600586 seconds
# INFO: 	Extracting triples associated to hasTerm
# INFO: 		Time extracting triples for property: 0.11299967765808105 seconds
# INFO: 	Extracting triples associated to hasContractParty
# INFO: 		Time extracting triples for property: 0.14204955101013184 seconds
# INFO: 	Extracting triples associated to hasPartyInRole
# INFO: 		Time extracting triples for property: 0.14548015594482422 seconds
# INFO: 	Extracting triples associated to hasContractualElement
# INFO: 		Time extracting triples for property: 0.1407773494720459 seconds
# INFO: 	Extracting triples associated to comprises
# INFO: 		Time extracting triples for property: 0.3153657913208008 seconds
# INFO: 	Extracting triples associated to hasCounterparty
# INFO: 		Time extracting triples for property: 0.13861680030822754 seconds
# INFO: 	Extracting triples associated to hasEffectiveDate
# INFO: 		Time extracting triples for property: 0.1466054916381836 seconds
# INFO: 	Extracting triples associated to hasDate
# INFO: 		Time extracting triples for property: 0.11403894424438477 seconds
# INFO: 	Extracting triples associated to hasEffectiveDateTimeStamp
# INFO: 		Time extracting triples for property: 0.12863564491271973 seconds
# INFO: 	Extracting triples associated to hasDateTimeStamp
# INFO: 		Time extracting triples for property: 0.11589574813842773 seconds
# INFO: 	Extracting triples associated to hasExecutionDate
# INFO: 		Time extracting triples for property: 0.1343233585357666 seconds
# INFO: 	Extracting triples associated to hasExecutionDateTimeStamp
# INFO: 		Time extracting triples for property: 0.12890124320983887 seconds
# INFO: 	Extracting triples associated to hasExtendablePeriod
# INFO: 		Time extracting triples for property: 0.13898301124572754 seconds
# INFO: 	Extracting triples associated to hasDatePeriod
# INFO: 		Time extracting triples for property: 0.16095685958862305 seconds
# INFO: 	Extracting triples associated to hasExtensionProvision
# INFO: 		Time extracting triples for property: 0.12111639976501465 seconds
# INFO: 	Extracting triples associated to hasGoverningJurisdiction
# INFO: 		Time extracting triples for property: 0.13102436065673828 seconds
# INFO: 	Extracting triples associated to isGovernedBy
# INFO: 		Time extracting triples for property: 0.16043829917907715 seconds
# INFO: 	Extracting triples associated to hasNonBindingTerm
# INFO: 		Time extracting triples for property: 0.20545506477355957 seconds
# INFO: 	Extracting triples associated to hasPrincipalParty
# INFO: 		Time extracting triples for property: 0.1390061378479004 seconds
# INFO: 	Extracting triples associated to hasDuration
# INFO: 		Time extracting triples for property: 0.14570999145507812 seconds
# INFO: 	Extracting triples associated to hasThirdParty
# INFO: 		Time extracting triples for property: 0.12476730346679688 seconds
# INFO: 	Extracting triples associated to isEvidenceFor
# INFO: 		Time extracting triples for property: 0.18899106979370117 seconds
# INFO: 	Extracting triples associated to isEvidencedBy
# INFO: 		Time extracting triples for property: 0.12562274932861328 seconds
# INFO: 	Extracting triples associated to isQualifiedBy
# INFO: 		Time extracting triples for property: 0.1078033447265625 seconds
# INFO: 	Extracting triples associated to isCharacterizedBy
# INFO: 		Time extracting triples for property: 0.1787090301513672 seconds
# INFO: 	Extracting triples associated to qualifies
# INFO: 		Time extracting triples for property: 0.10736322402954102 seconds
# INFO: 	Extracting triples associated to characterizes
# INFO: 		Time extracting triples for property: 0.12077713012695312 seconds
# INFO: 	Extracting triples associated to supersedes
# INFO: 		Time extracting triples for property: 0.12713885307312012 seconds
# INFO: 	Extracting triples associated to hasConstituent
# INFO: 		Time extracting triples for property: 0.1651904582977295 seconds
# INFO: 	Extracting triples associated to isConstituentOf
# INFO: 		Time extracting triples for property: 0.13212060928344727 seconds
# INFO: 	Extracting triples associated to hasDataSource
# INFO: 		Time extracting triples for property: 0.11230754852294922 seconds
# INFO: 	Extracting triples associated to hasDateOfIssuance
# INFO: 		Time extracting triples for property: 0.12952327728271484 seconds
# INFO: 	Extracting triples associated to hasStartDate
# INFO: 		Time extracting triples for property: 0.13688898086547852 seconds
# INFO: 	Extracting triples associated to hasExpirationDate
# INFO: 		Time extracting triples for property: 0.12858271598815918 seconds
# INFO: 	Extracting triples associated to hasEndDate
# INFO: 		Time extracting triples for property: 0.13735723495483398 seconds
# INFO: 	Extracting triples associated to hasRecord
# INFO: 		Time extracting triples for property: 0.17054390907287598 seconds
# INFO: 	Extracting triples associated to hasReportingPeriod
# INFO: 		Time extracting triples for property: 0.11078214645385742 seconds
# INFO: 	Extracting triples associated to hasTerminationDate
# INFO: 		Time extracting triples for property: 0.11285758018493652 seconds
# INFO: 	Extracting triples associated to isAbout
# INFO: 		Time extracting triples for property: 0.12685894966125488 seconds
# INFO: 	Extracting triples associated to records
# INFO: 		Time extracting triples for property: 0.10513973236083984 seconds
# INFO: 	Extracting triples associated to isIndexTo
# INFO: 		Time extracting triples for property: 0.1637134552001953 seconds
# INFO: 	Extracting triples associated to hasBusinessDayAdjustment
# INFO: 		Time extracting triples for property: 0.14636802673339844 seconds
# INFO: 	Extracting triples associated to hasBusinessDayConvention
# INFO: 		Time extracting triples for property: 0.12909555435180664 seconds
# INFO: 	Extracting triples associated to hasBusinessRecurrenceIntervalConvention
# INFO: 		Time extracting triples for property: 0.1295335292816162 seconds
# INFO: 	Extracting triples associated to holdsDuring
# INFO: 		Time extracting triples for property: 0.1724567413330078 seconds
# INFO: 	Extracting triples associated to hasAsOfDate
# INFO: 		Time extracting triples for property: 0.13103842735290527 seconds
# INFO: 	Extracting triples associated to hasCalendarPeriod
# INFO: 		Time extracting triples for property: 0.13067388534545898 seconds
# INFO: 	Extracting triples associated to hasDateAdded
# INFO: 		Time extracting triples for property: 0.1128387451171875 seconds
# INFO: 	Extracting triples associated to hasDateReceived
# INFO: 		Time extracting triples for property: 0.10808324813842773 seconds
# INFO: 	Extracting triples associated to hasDateTime
# INFO: 		Time extracting triples for property: 0.11308026313781738 seconds
# INFO: 	Extracting triples associated to hasFinalStub
# INFO: 		Time extracting triples for property: 0.12268829345703125 seconds
# INFO: 	Extracting triples associated to hasStub
# INFO: 		Time extracting triples for property: 0.12237691879272461 seconds
# INFO: 	Extracting triples associated to hasInitialStub
# INFO: 		Time extracting triples for property: 0.12366342544555664 seconds
# INFO: 	Extracting triples associated to hasOverallPeriod
# INFO: 		Time extracting triples for property: 0.19522333145141602 seconds
# INFO: 	Extracting triples associated to hasRecurrenceInterval
# INFO: 		Time extracting triples for property: 0.12949562072753906 seconds
# INFO: 	Extracting triples associated to hasRecurrenceStartDate
# INFO: 		Time extracting triples for property: 0.12273883819580078 seconds
# INFO: 	Extracting triples associated to hasSchedule
# INFO: 		Time extracting triples for property: 0.11142992973327637 seconds
# INFO: 	Extracting triples associated to hasTimeDirection
# INFO: 		Time extracting triples for property: 0.12954497337341309 seconds
# INFO: 	Extracting triples associated to isRelativeTo
# INFO: 		Time extracting triples for property: 0.13008785247802734 seconds
# INFO: 	Extracting triples associated to exemplifies
# INFO: 		Time extracting triples for property: 0.14729547500610352 seconds
# INFO: 	Extracting triples associated to isExemplifiedBy
# INFO: 		Time extracting triples for property: 0.14131784439086914 seconds
# INFO: 	Extracting triples associated to hasEventDate
# INFO: 		Time extracting triples for property: 0.13013124465942383 seconds
# INFO: 	Extracting triples associated to hasInput
# INFO: 		Time extracting triples for property: 0.11559748649597168 seconds
# INFO: 	Extracting triples associated to isInputTo
# INFO: 		Time extracting triples for property: 0.10711169242858887 seconds
# INFO: 	Extracting triples associated to hasOccurrence
# INFO: 		Time extracting triples for property: 0.1877155303955078 seconds
# INFO: 	Extracting triples associated to hasOutput
# INFO: 		Time extracting triples for property: 0.10695910453796387 seconds
# INFO: 	Extracting triples associated to isOutputFrom
# INFO: 		Time extracting triples for property: 0.10959744453430176 seconds
# INFO: 	Extracting triples associated to isTriggeredBy
# INFO: 		Time extracting triples for property: 0.1407182216644287 seconds
# INFO: 	Extracting triples associated to hasGoal
# INFO: 		Time extracting triples for property: 0.1661818027496338 seconds
# INFO: 	Extracting triples associated to hasObjective
# INFO: 		Time extracting triples for property: 0.2429969310760498 seconds
# INFO: 	Extracting triples associated to hasStrategy
# INFO: 		Time extracting triples for property: 0.11326456069946289 seconds
# INFO: 	Extracting triples associated to appliesIn
# INFO: 		Time extracting triples for property: 0.21057415008544922 seconds
# INFO: 	Extracting triples associated to hasReach
# INFO: 		Time extracting triples for property: 0.1994462013244629 seconds
# INFO: 	Extracting triples associated to hasCapacity
# INFO: 		Time extracting triples for property: 0.12361502647399902 seconds
# INFO: 	Extracting triples associated to isCapacityOf
# INFO: 		Time extracting triples for property: 0.12593913078308105 seconds
# INFO: 	Extracting triples associated to implements
# INFO: 		Time extracting triples for property: 0.1232137680053711 seconds
# INFO: 	Extracting triples associated to involves
# INFO: 		Time extracting triples for property: 0.11015582084655762 seconds
# INFO: 	Extracting triples associated to isImplementedBy
# INFO: 		Time extracting triples for property: 0.1067051887512207 seconds
# INFO: 	Extracting triples associated to implies
# INFO: 		Time extracting triples for property: 0.15890955924987793 seconds
# INFO: 	Extracting triples associated to isImpliedBy
# INFO: 		Time extracting triples for property: 0.14668822288513184 seconds
# INFO: 	Extracting triples associated to isConferredOn
# INFO: 		Time extracting triples for property: 0.16765999794006348 seconds
# INFO: 	Extracting triples associated to isLicensedBy
# INFO: 		Time extracting triples for property: 0.11868619918823242 seconds
# INFO: 	Extracting triples associated to licenses
# INFO: 		Time extracting triples for property: 0.13332271575927734 seconds
# INFO: 	Extracting triples associated to governs
# INFO: 		Time extracting triples for property: 0.15477991104125977 seconds
# INFO: 	Extracting triples associated to hasInForce
# INFO: 		Time extracting triples for property: 0.11519312858581543 seconds
# INFO: 	Extracting triples associated to isInForceIn
# INFO: 		Time extracting triples for property: 0.13869500160217285 seconds
# INFO: 	Extracting triples associated to employs
# INFO: 		Time extracting triples for property: 0.12348556518554688 seconds
# INFO: 	Extracting triples associated to playsActiveRoleThatDirectlyAffects
# INFO: 		Time extracting triples for property: 0.1053321361541748 seconds
# INFO: 	Extracting triples associated to hasEmployedParty
# INFO: 		Time extracting triples for property: 0.1416785717010498 seconds
# INFO: 	Extracting triples associated to hasOrganizationMember
# INFO: 		Time extracting triples for property: 0.20795130729675293 seconds
# INFO: 	Extracting triples associated to isEmployedIn
# INFO: 		Time extracting triples for property: 0.13908743858337402 seconds
# INFO: 	Extracting triples associated to hasEmployee
# INFO: 		Time extracting triples for property: 0.14583444595336914 seconds
# INFO: 	Extracting triples associated to actsOn
# INFO: 		Time extracting triples for property: 0.10689878463745117 seconds
# INFO: 	Extracting triples associated to isEmployeeOf
# INFO: 		Time extracting triples for property: 0.14011383056640625 seconds
# INFO: 	Extracting triples associated to hasEmployingParty
# INFO: 		Time extracting triples for property: 0.14070987701416016 seconds
# INFO: 	Extracting triples associated to hasMembership
# INFO: 		Time extracting triples for property: 0.14223480224609375 seconds
# INFO: 	Extracting triples associated to isEmployingParty
# INFO: 		Time extracting triples for property: 0.1499323844909668 seconds
# INFO: 	Extracting triples associated to isDomiciledIn
# INFO: 		Time extracting triples for property: 0.13934683799743652 seconds
# INFO: 	Extracting triples associated to isEmployedBy
# INFO: 		Time extracting triples for property: 0.12230324745178223 seconds
# INFO: 	Extracting triples associated to experiencesDirectly
# INFO: 		Time extracting triples for property: 0.10580992698669434 seconds
# INFO: 	Extracting triples associated to isOrganizationMember
# INFO: 		Time extracting triples for property: 0.12296557426452637 seconds
# INFO: 	Extracting triples associated to isAffectedBy
# INFO: 		Time extracting triples for property: 0.1043403148651123 seconds
# INFO: 	Extracting triples associated to isMembershipPartyIn
# INFO: 		Time extracting triples for property: 0.12315702438354492 seconds
# INFO: 	Extracting triples associated to hasActor
# INFO: 		Time extracting triples for property: 0.14227628707885742 seconds
# INFO: 	Extracting triples associated to hasUndergoer
# INFO: 		Time extracting triples for property: 0.14103150367736816 seconds
# INFO: 	Extracting triples associated to hasSubUnit
# INFO: 		Time extracting triples for property: 0.12267208099365234 seconds
# INFO: 	Extracting triples associated to hasPart
# INFO: 		Time extracting triples for property: 0.1388859748840332 seconds
# INFO: 	Extracting triples associated to isSubUnitOf
# INFO: 		Time extracting triples for property: 0.12851977348327637 seconds
# INFO: 	Extracting triples associated to actsIn
# INFO: 		Time extracting triples for property: 0.18779397010803223 seconds
# INFO: 	Extracting triples associated to undergoes
# INFO: 		Time extracting triples for property: 0.12141656875610352 seconds
# INFO: 	Extracting triples associated to isPartOf
# INFO: 		Time extracting triples for property: 0.1256880760192871 seconds
# INFO: 	Extracting triples associated to hasOwnedAsset
# INFO: 		Time extracting triples for property: 0.14173316955566406 seconds
# INFO: 	Extracting triples associated to isOwnedAsset
# INFO: 		Time extracting triples for property: 0.13844990730285645 seconds
# INFO: 	Extracting triples associated to hasOwningParty
# INFO: 		Time extracting triples for property: 0.14489030838012695 seconds
# INFO: 	Extracting triples associated to isOwningParty
# INFO: 		Time extracting triples for property: 0.1416490077972412 seconds
# INFO: 	Extracting triples associated to isAssetOf
# INFO: 		Time extracting triples for property: 0.1422276496887207 seconds
# INFO: 	Extracting triples associated to ownsAsset
# INFO: 		Time extracting triples for property: 0.1403663158416748 seconds
# INFO: 	Extracting triples associated to isOwnedBy
# INFO: 		Time extracting triples for property: 0.11163854598999023 seconds
# INFO: 	Extracting triples associated to owns
# INFO: 		Time extracting triples for property: 0.11852741241455078 seconds
# INFO: 	Extracting triples associated to directlyAffects
# INFO: 		Time extracting triples for property: 0.10721683502197266 seconds
# INFO: 	Extracting triples associated to experiencesWith
# INFO: 		Time extracting triples for property: 0.11569809913635254 seconds
# INFO: 	Extracting triples associated to isPlayedBy
# INFO: 		Time extracting triples for property: 0.28600382804870605 seconds
# INFO: 	Extracting triples associated to experiences
# INFO: 		Time extracting triples for property: 0.11290836334228516 seconds
# INFO: 	Extracting triples associated to isExperiencedBy
# INFO: 		Time extracting triples for property: 0.10620927810668945 seconds
# INFO: 	Extracting triples associated to playsRole
# INFO: 		Time extracting triples for property: 0.11320161819458008 seconds
# INFO: 	Extracting triples associated to hasActiveParty
# INFO: 		Time extracting triples for property: 0.10795378684997559 seconds
# INFO: 	Extracting triples associated to playsActiveRoleIn
# INFO: 		Time extracting triples for property: 0.10707354545593262 seconds
# INFO: 	Extracting triples associated to hasCommencementDate
# INFO: 		Time extracting triples for property: 0.20313310623168945 seconds
# INFO: 	Extracting triples associated to hasMailingAddress
# INFO: 		Time extracting triples for property: 0.14093589782714844 seconds
# INFO: 	Extracting triples associated to hasParty
# INFO: 		Time extracting triples for property: 0.11445045471191406 seconds
# INFO: 	Extracting triples associated to isAPartyTo
# INFO: 		Time extracting triples for property: 0.1576097011566162 seconds
# INFO: 	Extracting triples associated to hasRelatedPartyInRole
# INFO: 		Time extracting triples for property: 0.13061857223510742 seconds
# INFO: 	Extracting triples associated to hasThingInRole
# INFO: 		Time extracting triples for property: 0.11594510078430176 seconds
# INFO: 	Extracting triples associated to isDirectlyAffectedBy
# INFO: 		Time extracting triples for property: 0.10964655876159668 seconds
# INFO: 	Extracting triples associated to playsActiveRoleThatAffects
# INFO: 		Time extracting triples for property: 0.10839605331420898 seconds
# INFO: 	Extracting triples associated to hasIdentity
# INFO: 		Time extracting triples for property: 0.1699821949005127 seconds
# INFO: 	Extracting triples associated to hasIndividualPostcode
# INFO: 		Time extracting triples for property: 0.14117765426635742 seconds
# INFO: 	Extracting triples associated to hasPostdirectionalSymbol
# INFO: 		Time extracting triples for property: 0.13866114616394043 seconds
# INFO: 	Extracting triples associated to hasPredirectionalSymbol
# INFO: 		Time extracting triples for property: 0.14614462852478027 seconds
# INFO: 	Extracting triples associated to hasPrimaryAddressNumber
# INFO: 		Time extracting triples for property: 0.14063334465026855 seconds
# INFO: 	Extracting triples associated to hasSecondaryUnit
# INFO: 		Time extracting triples for property: 0.17016816139221191 seconds
# INFO: 	Extracting triples associated to hasStreetAddress
# INFO: 		Time extracting triples for property: 0.13935160636901855 seconds
# INFO: 	Extracting triples associated to hasStreetName
# INFO: 		Time extracting triples for property: 0.13885951042175293 seconds
# INFO: 	Extracting triples associated to hasStreetSuffix
# INFO: 		Time extracting triples for property: 0.1383969783782959 seconds
# INFO: 	Extracting triples associated to hasStructureName
# INFO: 		Time extracting triples for property: 0.12235546112060547 seconds
# INFO: 	Extracting triples associated to hasTransliteratedAddress
# INFO: 		Time extracting triples for property: 0.1770787239074707 seconds
# INFO: 	Extracting triples associated to hasBusinessCenter
# INFO: 		Time extracting triples for property: 0.12774920463562012 seconds
# INFO: 	Extracting triples associated to hasMunicipality
# INFO: 		Time extracting triples for property: 0.1305696964263916 seconds
# INFO: 	Extracting triples associated to hasCountry
# INFO: 		Time extracting triples for property: 0.13288354873657227 seconds
# INFO: 	Extracting triples associated to hasRegion
# INFO: 		Time extracting triples for property: 0.1130366325378418 seconds
# INFO: 	Extracting triples associated to hasCounty
# INFO: 		Time extracting triples for property: 0.11237192153930664 seconds
# INFO: 	Extracting triples associated to hasSubdivision
# INFO: 		Time extracting triples for property: 0.1286923885345459 seconds
# INFO: 	Extracting triples associated to hasCoverageArea
# INFO: 		Time extracting triples for property: 0.14679265022277832 seconds
# INFO: 	Extracting triples associated to isLocatedAt
# INFO: 		Time extracting triples for property: 0.1373450756072998 seconds
# INFO: 	Extracting triples associated to hasDimension
# INFO: 		Time extracting triples for property: 0.1288609504699707 seconds
# INFO: 	Extracting triples associated to hasFactor
# INFO: 		Time extracting triples for property: 0.1579296588897705 seconds
# INFO: 	Extracting triples associated to hasQuantityKind
# INFO: 		Time extracting triples for property: 0.14639687538146973 seconds
# INFO: 	Extracting triples associated to hasQuantityValue
# INFO: 		Time extracting triples for property: 0.11441779136657715 seconds
# INFO: 	Extracting triples associated to isDerivedFrom
# INFO: 		Time extracting triples for property: 0.13949084281921387 seconds
# INFO: 	Extracting triples associated to specializes
# INFO: 		Time extracting triples for property: 0.14087200164794922 seconds
# INFO: 	Extracting triples associated to appliesTo
# INFO: 		Time extracting triples for property: 0.23530197143554688 seconds
# INFO: 	Extracting triples associated to causes
# INFO: 		Time extracting triples for property: 0.10782265663146973 seconds
# INFO: 	Extracting triples associated to isCausedBy
# INFO: 		Time extracting triples for property: 0.11035728454589844 seconds
# INFO: 	Extracting triples associated to isIncludedIn
# INFO: 		Time extracting triples for property: 0.16790294647216797 seconds
# INFO: 	Extracting triples associated to confers
# INFO: 		Time extracting triples for property: 0.17318010330200195 seconds
# INFO: 	Extracting triples associated to isConferredBy
# INFO: 		Time extracting triples for property: 0.21411848068237305 seconds
# INFO: 	Extracting triples associated to controls
# INFO: 		Time extracting triples for property: 0.10709190368652344 seconds
# INFO: 	Extracting triples associated to isControlledBy
# INFO: 		Time extracting triples for property: 0.1103217601776123 seconds
# INFO: 	Extracting triples associated to defines
# INFO: 		Time extracting triples for property: 0.29584717750549316 seconds
# INFO: 	Extracting triples associated to represents
# INFO: 		Time extracting triples for property: 0.1056220531463623 seconds
# INFO: 	Extracting triples associated to isDefinedIn
# INFO: 		Time extracting triples for property: 0.3103518486022949 seconds
# INFO: 	Extracting triples associated to describes
# INFO: 		Time extracting triples for property: 0.12814545631408691 seconds
# INFO: 	Extracting triples associated to isDescribedBy
# INFO: 		Time extracting triples for property: 0.11128783226013184 seconds
# INFO: 	Extracting triples associated to designates
# INFO: 		Time extracting triples for property: 0.10556554794311523 seconds
# INFO: 	Extracting triples associated to isDesignatedBy
# INFO: 		Time extracting triples for property: 0.10957574844360352 seconds
# INFO: 	Extracting triples associated to embodies
# INFO: 		Time extracting triples for property: 0.10583019256591797 seconds
# INFO: 	Extracting triples associated to evaluates
# INFO: 		Time extracting triples for property: 0.10792708396911621 seconds
# INFO: 	Extracting triples associated to isEvaluatedBy
# INFO: 		Time extracting triples for property: 0.10535430908203125 seconds
# INFO: 	Extracting triples associated to exchanges
# INFO: 		Time extracting triples for property: 0.10663223266601562 seconds
# INFO: 	Extracting triples associated to generates
# INFO: 		Time extracting triples for property: 0.1085970401763916 seconds
# INFO: 	Extracting triples associated to isGeneratedBy
# INFO: 		Time extracting triples for property: 0.11542415618896484 seconds
# INFO: 	Extracting triples associated to hasContext
# INFO: 		Time extracting triples for property: 0.215789794921875 seconds
# INFO: 	Extracting triples associated to hasDesignation
# INFO: 		Time extracting triples for property: 0.1411590576171875 seconds
# INFO: 	Extracting triples associated to hasRepresentation
# INFO: 		Time extracting triples for property: 0.10773086547851562 seconds
# INFO: 	Extracting triples associated to holds
# INFO: 		Time extracting triples for property: 0.12231683731079102 seconds
# INFO: 	Extracting triples associated to isHeldBy
# INFO: 		Time extracting triples for property: 0.11006045341491699 seconds
# INFO: 	Extracting triples associated to isIssuedBy
# INFO: 		Time extracting triples for property: 0.1237032413482666 seconds
# INFO: 	Extracting triples associated to isProvidedBy
# INFO: 		Time extracting triples for property: 0.12357497215270996 seconds
# INFO: 	Extracting triples associated to issues
# INFO: 		Time extracting triples for property: 0.12424635887145996 seconds
# INFO: 	Extracting triples associated to isManagedBy
# INFO: 		Time extracting triples for property: 0.10763764381408691 seconds
# INFO: 	Extracting triples associated to manages
# INFO: 		Time extracting triples for property: 0.11050605773925781 seconds
# INFO: 	Extracting triples associated to isMandatedBy
# INFO: 		Time extracting triples for property: 0.14362001419067383 seconds
# INFO: 	Extracting triples associated to mandates
# INFO: 		Time extracting triples for property: 0.10734415054321289 seconds
# INFO: 	Extracting triples associated to isProducedBy
# INFO: 		Time extracting triples for property: 0.10630941390991211 seconds
# INFO: 	Extracting triples associated to produces
# INFO: 		Time extracting triples for property: 0.10698843002319336 seconds
# INFO: 	Extracting triples associated to provides
# INFO: 		Time extracting triples for property: 0.12488150596618652 seconds
# INFO: 	Extracting triples associated to hasAnchorDate
# INFO: 		Time extracting triples for property: 0.1310417652130127 seconds
# INFO: 	Extracting triples associated to hasApplicableDatePeriod
# INFO: 		Time extracting triples for property: 0.12324666976928711 seconds
# INFO: 	Extracting triples associated to hasArgument
# INFO: 		Time extracting triples for property: 0.26618027687072754 seconds
# INFO: 	Extracting triples associated to hasExpression
# INFO: 		Time extracting triples for property: 0.21558547019958496 seconds
# INFO: 	Extracting triples associated to hasFixedComparativeDate
# INFO: 		Time extracting triples for property: 0.11456751823425293 seconds
# INFO: 	Extracting triples associated to hasFormula
# INFO: 		Time extracting triples for property: 0.1309056282043457 seconds
# INFO: 	Extracting triples associated to hasMinuend
# INFO: 		Time extracting triples for property: 0.13415932655334473 seconds
# INFO: 	Extracting triples associated to hasObservedValue
# INFO: 		Time extracting triples for property: 0.16483211517333984 seconds
# INFO: 	Extracting triples associated to hasPeriodicity
# INFO: 		Time extracting triples for property: 0.1581120491027832 seconds
# INFO: 	Extracting triples associated to hasReferencePeriod
# INFO: 		Time extracting triples for property: 0.13158154487609863 seconds
# INFO: 	Extracting triples associated to hasRelativeComparativeDate
# INFO: 		Time extracting triples for property: 0.11197781562805176 seconds
# INFO: 	Extracting triples associated to hasRelativeComparativePeriod
# INFO: 		Time extracting triples for property: 0.11098885536193848 seconds
# INFO: 	Extracting triples associated to hasReleaseDate
# INFO: 		Time extracting triples for property: 0.11445736885070801 seconds
# INFO: 	Extracting triples associated to hasSubtrahend
# INFO: 		Time extracting triples for property: 0.13390636444091797 seconds
# INFO: 	Extracting triples associated to isValueOf
# INFO: 		Time extracting triples for property: 0.1327686309814453 seconds
# INFO: 	Extracting triples associated to classifies
# INFO: 		Time extracting triples for property: 0.17478322982788086 seconds
# INFO: 	Extracting triples associated to isClassifiedBy
# INFO: 		Time extracting triples for property: 0.14189457893371582 seconds
# INFO: 	Extracting triples associated to hasSubregion
# INFO: 		Time extracting triples for property: 0.12692546844482422 seconds
# INFO: 	Extracting triples associated to isSubregionOf
# INFO: 		Time extracting triples for property: 0.1257762908935547 seconds
# INFO: 	Extracting triples associated to uses
# INFO: 		Time extracting triples for property: 0.14007329940795898 seconds
# INFO: 	Extracting triples associated to usesAdministrativeLanguage
# INFO: 		Time extracting triples for property: 0.14226245880126953 seconds
# INFO: 	Extracting triples associated to denotes
# INFO: 		Time extracting triples for property: 0.3669710159301758 seconds
# INFO: 	Extracting triples associated to hasDenotation
# INFO: 		Time extracting triples for property: 0.10864663124084473 seconds
# INFO: 	Extracting triples associated to hasEarlierForm
# INFO: 		Time extracting triples for property: 0.1246490478515625 seconds
# INFO: 	Extracting triples associated to hasMember
# INFO: 		Time extracting triples for property: 0.22724485397338867 seconds
# INFO: 	Extracting triples associated to isMemberOf
# INFO: 		Time extracting triples for property: 0.21242904663085938 seconds
# INFO: 	Extracting triples associated to identifies
# INFO: 		Time extracting triples for property: 0.5072593688964844 seconds
# INFO: 	Extracting triples associated to isIdentifiedBy
# INFO: 		Time extracting triples for property: 0.19201278686523438 seconds
# INFO: 	Extracting data property assertions
# INFO: 		Time extracting data property assertions: 2.3204448223114014 seconds
# INFO: 	Extracting complex equivalence axioms
# INFO: 		Time extracting complex equivalence axioms: 5.294804573059082 seconds
# INFO: 	Extracting annotations.
# INFO: 		Time extracting annotations: 1.7520287036895752 seconds
# INFO: Projection created into a Graph object (RDFlib library)
# INFO: Projection saved into turtle file: /home/kaishuo/accenture/OWL2Vec-Star/cache/projection.ttl
#
# Extract classes and individuals ...
#
# Extract axioms ...
#
# Extract annotations ...
#
# Generate URI document ...
# Extracted 6962 walks for 456 seed entities
# Extracted 946 axiom sentences
#
# Generate literal document ...
# Extracted 4 annotation sentences
# URI_Doc: 7908, Lit_Doc: 7912, Mix_Doc: 0
# Time for document construction: 66.14570379257202 seconds
#
# Train the embedding model ...
# INFO: collecting all words and their counts
# INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO: PROGRESS: at sentence #10000, processed 51660 words, keeping 1726 word types
# INFO: collected 1823 word types from a corpus of 81449 raw words and 15820 sentences
# INFO: Creating a fresh vocabulary
# INFO: Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 1823 unique words (100.00% of original 1823, drops 0)', 'datetime': '2024-02-26T17:53:06.921156', 'gensim': '4.3.2', 'python': '3.11.7 (main, Dec 15 2023, 18:12:31) [GCC 11.2.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'prepare_vocab'}
# INFO: Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 81449 word corpus (100.00% of original 81449, drops 0)', 'datetime': '2024-02-26T17:53:06.922225', 'gensim': '4.3.2', 'python': '3.11.7 (main, Dec 15 2023, 18:12:31) [GCC 11.2.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'prepare_vocab'}
# INFO: deleting the raw counts dictionary of 1823 items
# INFO: sample=0.001 downsamples 60 most-common words
# INFO: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 58486.158722517 word corpus (71.8%% of prior 81449)', 'datetime': '2024-02-26T17:53:06.928050', 'gensim': '4.3.2', 'python': '3.11.7 (main, Dec 15 2023, 18:12:31) [GCC 11.2.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'prepare_vocab'}
# INFO: estimated required memory for 1823 words and 100 dimensions: 2369900 bytes
# INFO: resetting layer weights
# INFO: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-02-26T17:53:06.939237', 'gensim': '4.3.2', 'python': '3.11.7 (main, Dec 15 2023, 18:12:31) [GCC 11.2.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'build_vocab'}
# INFO: Word2Vec lifecycle event {'msg': 'training model with 8 workers on 1823 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=25 window=5 shrink_windows=True', 'datetime': '2024-02-26T17:53:06.939322', 'gensim': '4.3.2', 'python': '3.11.7 (main, Dec 15 2023, 18:12:31) [GCC 11.2.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'train'}
# INFO: EPOCH 0: training on 81449 raw words (58544 effective words) took 0.1s, 440802 effective words/s
# INFO: EPOCH 1: training on 81449 raw words (58623 effective words) took 0.1s, 454293 effective words/s
# INFO: EPOCH 2: training on 81449 raw words (58550 effective words) took 0.1s, 462889 effective words/s
# INFO: EPOCH 3: training on 81449 raw words (58466 effective words) took 0.1s, 477729 effective words/s
# INFO: EPOCH 4: training on 81449 raw words (58412 effective words) took 0.2s, 360649 effective words/s
# INFO: EPOCH 5: training on 81449 raw words (58630 effective words) took 0.1s, 533462 effective words/s
# INFO: EPOCH 6: training on 81449 raw words (58585 effective words) took 0.1s, 531619 effective words/s
# INFO: EPOCH 7: training on 81449 raw words (58624 effective words) took 0.1s, 456525 effective words/s
# INFO: EPOCH 8: training on 81449 raw words (58572 effective words) took 0.1s, 551346 effective words/s
# INFO: EPOCH 9: training on 81449 raw words (58451 effective words) took 0.1s, 552984 effective words/s
# INFO: Word2Vec lifecycle event {'msg': 'training on 814490 raw words (585457 effective words) took 1.3s, 447833 effective words/s', 'datetime': '2024-02-26T17:53:08.246702', 'gensim': '4.3.2', 'python': '3.11.7 (main, Dec 15 2023, 18:12:31) [GCC 11.2.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'train'}
# INFO: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=1823, vector_size=100, alpha=0.025>', 'datetime': '2024-02-26T17:53:08.246796', 'gensim': '4.3.2', 'python': '3.11.7 (main, Dec 15 2023, 18:12:31) [GCC 11.2.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'created'}
# INFO: Word2Vec lifecycle event {'fname_or_handle': '/home/kaishuo/accenture/OWL2Vec-Star/cache/output', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-02-26T17:53:08.246912', 'gensim': '4.3.2', 'python': '3.11.7 (main, Dec 15 2023, 18:12:31) [GCC 11.2.0]', 'platform': 'Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35', 'event': 'saving'}
# INFO: not storing attribute cum_table
# INFO: saved /home/kaishuo/accenture/OWL2Vec-Star/cache/output
# Time for learning the embedding model: 1.3439579010009766 seconds
# Model saved. Done!

# %%
import os
import time
import argparse
import random
import multiprocessing
import gensim
import configparser

from owl2vec_star.lib.RDF2Vec_Embed import get_rdf2vec_walks
from owl2vec_star.lib.Label import pre_process_words, URI_parse
from owl2vec_star.lib.Onto_Projection import Reasoner, OntologyProjection

parser = argparse.ArgumentParser()
parser.add_argument("--ontology_file", type=str, default=None, help="The input ontology for embedding")
parser.add_argument("--embedding_dir", type=str, default=None, help="The output embedding directory")
parser.add_argument("--config_file", type=str, default='default.cfg', help="Configuration file")
parser.add_argument("--URI_Doc", help="Using URI document", action="store_true")
parser.add_argument("--Lit_Doc", help="Using literal document", action="store_true")
parser.add_argument("--Mix_Doc", help="Using mixture document", action="store_true")
FLAGS, unparsed = parser.parse_known_args()

# read and combine configurations
# overwrite the parameters in the configuration file by the command parameters
config = configparser.ConfigParser()
config.read(FLAGS.config_file)
if FLAGS.ontology_file is not None:
    config['BASIC']['ontology_file'] = FLAGS.ontology_file
if FLAGS.embedding_dir is not None:
    config['BASIC']['embedding_dir'] = FLAGS.embedding_dir
if FLAGS.URI_Doc:
    config['DOCUMENT']['URI_Doc'] = 'yes'
if FLAGS.Lit_Doc:
    config['DOCUMENT']['Lit_Doc'] = 'yes'
if FLAGS.Mix_Doc:
    config['DOCUMENT']['Mix_Doc'] = 'yes'
if 'cache_dir' not in config['DOCUMENT']:
    config['DOCUMENT']['cache_dir'] = './cache'
if not os.path.exists(config['DOCUMENT']['cache_dir']):
    os.mkdir(config['DOCUMENT']['cache_dir'])
if 'embedding_dir' not in config['BASIC']:
    config['BASIC']['embedding_dir'] = os.path.join(config['DOCUMENT']['cache_dir'], 'output')

start_time = time.time()
if ('ontology_projection' in config['DOCUMENT'] and config['DOCUMENT']['ontology_projection'] == 'yes') or \
        'pre_entity_file' not in config['DOCUMENT'] or 'pre_axiom_file' not in config['DOCUMENT'] or \
        'pre_annotation_file' not in config['DOCUMENT']:
    print('\n Access the ontology ...')
    projection = OntologyProjection(config['BASIC']['ontology_file'], reasoner=Reasoner.STRUCTURAL, only_taxonomy=False,
                                    bidirectional_taxonomy=True, include_literals=True, avoid_properties=set(),
                                    additional_preferred_labels_annotations=set(),
                                    additional_synonyms_annotations=set(),
                                    memory_reasoner='13351')
else:
    projection = None

# Ontology projection
if 'ontology_projection' in config['DOCUMENT'] and config['DOCUMENT']['ontology_projection'] == 'yes':
    print('\nCalculate the ontology projection ...')
    projection.extractProjection()
    onto_projection_file = os.path.join(config['DOCUMENT']['cache_dir'], 'projection.ttl')
    projection.saveProjectionGraph(onto_projection_file)
    ontology_file = onto_projection_file
else:
    ontology_file = config['BASIC']['ontology_file']

# Extract and save seed entities (classes and individuals)
# Or read entities specified by the user
if 'pre_entity_file' in config['DOCUMENT']:
    entities = [line.strip() for line in open(config['DOCUMENT']['pre_entity_file']).readlines()]
else:
    print('\nExtract classes and individuals ...')
    projection.extractEntityURIs()
    classes = projection.getClassURIs()
    individuals = projection.getIndividualURIs()
    entities = classes.union(individuals)
    with open(os.path.join(config['DOCUMENT']['cache_dir'], 'entities.txt'), 'w') as f:
        for e in entities:
            f.write('%s\n' % e)

# Extract axioms in Manchester Syntax if it is not pre_axiom_file is not set
if 'pre_axiom_file' not in config['DOCUMENT']:
    print('\nExtract axioms ...')
    projection.createManchesterSyntaxAxioms()
    with open(os.path.join(config['DOCUMENT']['cache_dir'], 'axioms.txt'), 'w') as f:
        for ax in projection.axioms_manchester:
            f.write('%s\n' % ax)

# If pre_annotation_file is set, directly read annotations
# else, read annotations including rdfs:label and other literals from the ontology
#   Extract annotations: 1) English label of each entity, by rdfs:label or skos:preferredLabel
#                        2) None label annotations as sentences of the literal document
uri_label, annotations = dict(), list()

if 'pre_annotation_file' in config['DOCUMENT']:
    with open(config['DOCUMENT']['pre_annotation_file']) as f:
        for line in f.readlines():
            tmp = line.strip().split()
            if tmp[1] == 'http://www.w3.org/2000/01/rdf-schema#label':
                uri_label[tmp[0]] = pre_process_words(tmp[2:])
            else:
                annotations.append([tmp[0]] + tmp[2:])

else:
    print('\nExtract annotations ...')
    projection.indexAnnotations()
    for e in entities:
        if e in projection.entityToPreferredLabels and len(projection.entityToPreferredLabels[e]) > 0:
            label = list(projection.entityToPreferredLabels[e])[0]
            uri_label[e] = pre_process_words(words=label.split())
    for e in entities:
        if e in projection.entityToAllLexicalLabels:
            for v in projection.entityToAllLexicalLabels[e]:
                if (v is not None) and \
                        (not (e in projection.entityToPreferredLabels and v in projection.entityToPreferredLabels[e])):
                    annotation = [e] + v.split()
                    annotations.append(annotation)

    with open(os.path.join(config['DOCUMENT']['cache_dir'], 'annotations.txt'), 'w') as f:
        for e in projection.entityToPreferredLabels:
            for v in projection.entityToPreferredLabels[e]:
                f.write('%s preferred_label %s\n' % (e, v))
        for a in annotations:
            f.write('%s\n' % ' '.join(a))


# read URI document
# two parts: walks, axioms (if the axiom file exists)
walk_sentences, axiom_sentences, URI_Doc = list(), list(), list()
if 'URI_Doc' in config['DOCUMENT'] and config['DOCUMENT']['URI_Doc'] == 'yes':
    print('\nGenerate URI document ...')
    walks_ = get_rdf2vec_walks(onto_file=ontology_file, walker_type=config['DOCUMENT']['walker'],
                               walk_depth=int(config['DOCUMENT']['walk_depth']), classes=entities)
    print('Extracted %d walks for %d seed entities' % (len(walks_), len(entities)))
    walk_sentences += [list(map(str, x)) for x in walks_]

    axiom_file = os.path.join(config['DOCUMENT']['cache_dir'], 'axioms.txt')
    if os.path.exists(axiom_file):
        for line in open(axiom_file).readlines():
            axiom_sentence = [item for item in line.strip().split()]
            axiom_sentences.append(axiom_sentence)
    print('Extracted %d axiom sentences' % len(axiom_sentences))
    URI_Doc = walk_sentences + axiom_sentences


# Some entities have English labels
# Keep the name of built-in properties (those starting with http://www.w3.org)
# Some entities have no labels, then use the words in their URI name
def label_item(item):
    if item in uri_label:
        return uri_label[item]
    elif item.startswith('http://www.w3.org'):
        return [item.split('#')[1].lower()]
    elif item.startswith('http://'):
        return URI_parse(uri=item)
    else:
        return [item.lower()]


# read literal document
# two parts: literals in the annotations (subject's label + literal words)
#            replacing walk/axiom sentences by words in their labels
Lit_Doc = list()
if 'Lit_Doc' in config['DOCUMENT'] and config['DOCUMENT']['Lit_Doc'] == 'yes':
    print('\nGenerate literal document ...')
    for annotation in annotations:
        processed_words = pre_process_words(annotation[1:])
        if len(processed_words) > 0:
            Lit_Doc.append(label_item(item=annotation[0]) + processed_words)
    print('Extracted %d annotation sentences' % len(Lit_Doc))

    for sentence in walk_sentences:
        lit_sentence = list()
        for item in sentence:
            lit_sentence += label_item(item=item)
        Lit_Doc.append(lit_sentence)

    for sentence in axiom_sentences:
        lit_sentence = list()
        for item in sentence:
            lit_sentence += label_item(item=item)
        Lit_Doc.append(lit_sentence)

# read mixture document
# for each axiom/walk sentence, all): for each entity, keep its entity URI, replace the others by label words
#                            random): randomly select one entity, keep its entity URI, replace the others by label words
Mix_Doc = list()
if 'Mix_Doc' in config['DOCUMENT'] and config['DOCUMENT']['Mix_Doc'] == 'yes':
    print('\nGenerate mixture document ...')
    for sentence in walk_sentences + axiom_sentences:
        if config['DOCUMENT']['Mix_Type'] == 'all':
            for index in range(len(sentence)):
                mix_sentence = list()
                for i, item in enumerate(sentence):
                    mix_sentence += [item] if i == index else label_item(item=item)
                Mix_Doc.append(mix_sentence)
        elif config['DOCUMENT']['Mix_Type'] == 'random':
            random_index = random.randint(0, len(sentence) - 1)
            mix_sentence = list()
            for i, item in enumerate(sentence):
                mix_sentence += [item] if i == random_index else label_item(item=item)
            Mix_Doc.append(mix_sentence)

print('URI_Doc: %d, Lit_Doc: %d, Mix_Doc: %d' % (len(URI_Doc), len(Lit_Doc), len(Mix_Doc)))
all_doc = URI_Doc + Lit_Doc + Mix_Doc
# Out:
# INFO: There are 17076 triples in the ontology
# INFO: Creating ontology graph projection...
# INFO: 	Extracting subsumption triples
#  Access the ontology ...
#
# Calculate the ontology projection ...
# INFO: 		Time extracting subsumption: 0.32247233390808105 seconds
# INFO: 	Extracting equivalence triples
# INFO: 		Time extracting equivalences: 0.021766185760498047 seconds
# INFO: 	Extracting class membership triples.
# INFO: 		Time extracting class membership: 1.100654125213623 seconds
# INFO: 	Extracting sameAs triples
# INFO: 		Time extracting sameAs: 0.008609294891357422 seconds
# INFO: 	Extracting triples associated to hasSpecificationVersion
# INFO: 		Time extracting triples for property: 0.17271637916564941 seconds
# INFO: 	Extracting triples associated to isVersionOf
# INFO: 		Time extracting triples for property: 0.1871175765991211 seconds
# INFO: 	Extracting triples associated to isReflectedIn
# INFO: 		Time extracting triples for property: 0.14392542839050293 seconds
# INFO: 	Extracting triples associated to reflects
# INFO: 		Time extracting triples for property: 0.13981986045837402 seconds
# INFO: 	Extracting triples associated to broadMatch
# INFO: 		Time extracting triples for property: 0.17357587814331055 seconds
# INFO: 	Extracting triples associated to broader
# INFO: 		Time extracting triples for property: 0.13270926475524902 seconds
# INFO: 	Extracting triples associated to mappingRelation
# INFO: 		Time extracting triples for property: 0.1238698959350586 seconds
# INFO: 	Extracting triples associated to narrowMatch
# INFO: 		Time extracting triples for property: 0.12383031845092773 seconds
# INFO: 	Extracting triples associated to broaderTransitive
# INFO: 		Time extracting triples for property: 0.1253213882446289 seconds
# INFO: 	Extracting triples associated to narrower
# INFO: 		Time extracting triples for property: 0.12079858779907227 seconds
# INFO: 	Extracting triples associated to semanticRelation
# INFO: 		Time extracting triples for property: 0.13756418228149414 seconds
# INFO: 	Extracting triples associated to narrowerTransitive
# INFO: 		Time extracting triples for property: 0.12363839149475098 seconds
# INFO: 	Extracting triples associated to closeMatch
# INFO: 		Time extracting triples for property: 0.12142777442932129 seconds
# INFO: 	Extracting triples associated to exactMatch
# INFO: 		Time extracting triples for property: 0.13274216651916504 seconds
# INFO: 	Extracting triples associated to hasTopConcept
# INFO: 		Time extracting triples for property: 0.13908624649047852 seconds
# INFO: 	Extracting triples associated to topConceptOf
# INFO: 		Time extracting triples for property: 0.13710737228393555 seconds
# INFO: 	Extracting triples associated to inScheme
# INFO: 		Time extracting triples for property: 0.1259765625 seconds
# INFO: 	Extracting triples associated to member
# INFO: 		Time extracting triples for property: 0.15217804908752441 seconds
# INFO: 	Extracting triples associated to memberList
# INFO: 		Time extracting triples for property: 0.13906478881835938 seconds
# INFO: 	Extracting triples associated to related
# INFO: 		Time extracting triples for property: 0.12819552421569824 seconds
# INFO: 	Extracting triples associated to relatedMatch
# INFO: 		Time extracting triples for property: 0.1320185661315918 seconds
# INFO: 	Extracting triples associated to hasDateOfIncorporation
# INFO: 		Time extracting triples for property: 0.1346573829650879 seconds
# INFO: 	Extracting triples associated to hasExplicitDate
# INFO: 		Time extracting triples for property: 0.12998175621032715 seconds
# INFO: 	Extracting triples associated to hasDateOfRegistration
# INFO: 		Time extracting triples for property: 0.12963628768920898 seconds
# INFO: 	Extracting triples associated to hasIssuedCapital
# INFO: 		Time extracting triples for property: 0.13266944885253906 seconds
# INFO: 	Extracting triples associated to hasMonetaryAmount
# INFO: 		Time extracting triples for property: 0.23115777969360352 seconds
# INFO: 	Extracting triples associated to isConstitutedBy
# INFO: 		Time extracting triples for property: 0.15355587005615234 seconds
# INFO: 	Extracting triples associated to isIncorporatedIn
# INFO: 		Time extracting triples for property: 0.15632915496826172 seconds
# INFO: 	Extracting triples associated to isOrganizedIn
# INFO: 		Time extracting triples for property: 0.15633726119995117 seconds
# INFO: 	Extracting triples associated to hasEquity
# INFO: 		Time extracting triples for property: 0.14002323150634766 seconds
# INFO: 	Extracting triples associated to has
# INFO: 		Time extracting triples for property: 0.1528482437133789 seconds
# INFO: 	Extracting triples associated to hasHeadquartersAddress
# INFO: 		Time extracting triples for property: 0.1304776668548584 seconds
# INFO: 	Extracting triples associated to hasOperatingAddress
# INFO: 		Time extracting triples for property: 0.13716363906860352 seconds
# INFO: 	Extracting triples associated to hasAddress
# INFO: 		Time extracting triples for property: 0.14959001541137695 seconds
# INFO: 	Extracting triples associated to hasRegisteredAddress
# INFO: 		Time extracting triples for property: 0.1490168571472168 seconds
# INFO: 	Extracting triples associated to isRecognizedIn
# INFO: 		Time extracting triples for property: 0.19379615783691406 seconds
# INFO: 	Extracting triples associated to hasBaseCurrency
# INFO: 		Time extracting triples for property: 0.14604544639587402 seconds
# INFO: 	Extracting triples associated to hasCurrency
# INFO: 		Time extracting triples for property: 0.19616913795471191 seconds
# INFO: 	Extracting triples associated to hasMeasurementUnit
# INFO: 		Time extracting triples for property: 0.17467784881591797 seconds
# INFO: 	Extracting triples associated to hasDealtCurrency
# INFO: 		Time extracting triples for property: 0.14442729949951172 seconds
# INFO: 	Extracting triples associated to hasNotionalAmount
# INFO: 		Time extracting triples for property: 0.15255308151245117 seconds
# INFO: 	Extracting triples associated to hasPrice
# INFO: 		Time extracting triples for property: 0.1386733055114746 seconds
# INFO: 	Extracting triples associated to isPriceFor
# INFO: 		Time extracting triples for property: 0.1586778163909912 seconds
# INFO: 	Extracting triples associated to refersTo
# INFO: 		Time extracting triples for property: 0.16167974472045898 seconds
# INFO: 	Extracting triples associated to isTenderIn
# INFO: 		Time extracting triples for property: 0.12441349029541016 seconds
# INFO: 	Extracting triples associated to isUsedBy
# INFO: 		Time extracting triples for property: 0.15549564361572266 seconds
# INFO: 	Extracting triples associated to hasStructuredName
# INFO: 		Time extracting triples for property: 0.18063759803771973 seconds
# INFO: 	Extracting triples associated to isStructuredNameOf
# INFO: 		Time extracting triples for property: 0.18875527381896973 seconds
# INFO: 	Extracting triples associated to hasAgeOfMajority
# INFO: 		Time extracting triples for property: 0.14946603775024414 seconds
# INFO: 	Extracting triples associated to hasAge
# INFO: 		Time extracting triples for property: 0.14416861534118652 seconds
# INFO: 	Extracting triples associated to hasCitizenship
# INFO: 		Time extracting triples for property: 0.2561361789703369 seconds
# INFO: 	Extracting triples associated to hasDateOfBirth
# INFO: 		Time extracting triples for property: 0.16245651245117188 seconds
# INFO: 	Extracting triples associated to hasDateOfDeath
# INFO: 		Time extracting triples for property: 0.2018744945526123 seconds
# INFO: 	Extracting triples associated to hasMinimumLegalWorkingAge
# INFO: 		Time extracting triples for property: 0.18558359146118164 seconds
# INFO: 	Extracting triples associated to hasPlaceOfBirth
# INFO: 		Time extracting triples for property: 0.16136527061462402 seconds
# INFO: 	Extracting triples associated to hasPrimaryResidence
# INFO: 		Time extracting triples for property: 0.1432642936706543 seconds
# INFO: 	Extracting triples associated to hasResidence
# INFO: 		Time extracting triples for property: 0.1576988697052002 seconds
# INFO: 	Extracting triples associated to hasObligation
# INFO: 		Time extracting triples for property: 0.14837646484375 seconds
# INFO: 	Extracting triples associated to isObligationOf
# INFO: 		Time extracting triples for property: 0.14905595779418945 seconds
# INFO: 	Extracting triples associated to definesTermsFor
# INFO: 		Time extracting triples for property: 0.1352851390838623 seconds
# INFO: 	Extracting triples associated to hasContractDuration
# INFO: 		Time extracting triples for property: 0.15088534355163574 seconds
# INFO: 	Extracting triples associated to hasTerm
# INFO: 		Time extracting triples for property: 0.13179969787597656 seconds
# INFO: 	Extracting triples associated to hasContractParty
# INFO: 		Time extracting triples for property: 0.15432000160217285 seconds
# INFO: 	Extracting triples associated to hasPartyInRole
# INFO: 		Time extracting triples for property: 0.15776824951171875 seconds
# INFO: 	Extracting triples associated to hasContractualElement
# INFO: 		Time extracting triples for property: 0.1608138084411621 seconds
# INFO: 	Extracting triples associated to comprises
# INFO: 		Time extracting triples for property: 0.3380730152130127 seconds
# INFO: 	Extracting triples associated to hasCounterparty
# INFO: 		Time extracting triples for property: 0.15542197227478027 seconds
# INFO: 	Extracting triples associated to hasEffectiveDate
# INFO: 		Time extracting triples for property: 0.16158652305603027 seconds
# INFO: 	Extracting triples associated to hasDate
# INFO: 		Time extracting triples for property: 0.19938945770263672 seconds
# INFO: 	Extracting triples associated to hasEffectiveDateTimeStamp
# INFO: 		Time extracting triples for property: 0.22626042366027832 seconds
# INFO: 	Extracting triples associated to hasDateTimeStamp
# INFO: 		Time extracting triples for property: 0.16878509521484375 seconds
# INFO: 	Extracting triples associated to hasExecutionDate
# INFO: 		Time extracting triples for property: 0.19794440269470215 seconds
# INFO: 	Extracting triples associated to hasExecutionDateTimeStamp
# INFO: 		Time extracting triples for property: 0.16735053062438965 seconds
# INFO: 	Extracting triples associated to hasExtendablePeriod
# INFO: 		Time extracting triples for property: 0.16695380210876465 seconds
# INFO: 	Extracting triples associated to hasDatePeriod
# INFO: 		Time extracting triples for property: 0.18094754219055176 seconds
# INFO: 	Extracting triples associated to hasExtensionProvision
# INFO: 		Time extracting triples for property: 0.2691993713378906 seconds
# INFO: 	Extracting triples associated to hasGoverningJurisdiction
# INFO: 		Time extracting triples for property: 0.14254498481750488 seconds
# INFO: 	Extracting triples associated to isGovernedBy
# INFO: 		Time extracting triples for property: 0.1736438274383545 seconds
# INFO: 	Extracting triples associated to hasNonBindingTerm
# INFO: 		Time extracting triples for property: 0.18438386917114258 seconds
# INFO: 	Extracting triples associated to hasPrincipalParty
# INFO: 		Time extracting triples for property: 0.21876811981201172 seconds
# INFO: 	Extracting triples associated to hasDuration
# INFO: 		Time extracting triples for property: 0.22730398178100586 seconds
# INFO: 	Extracting triples associated to hasThirdParty
# INFO: 		Time extracting triples for property: 0.15259504318237305 seconds
# INFO: 	Extracting triples associated to isEvidenceFor
# INFO: 		Time extracting triples for property: 0.21605920791625977 seconds
# INFO: 	Extracting triples associated to isEvidencedBy
# INFO: 		Time extracting triples for property: 0.1742098331451416 seconds
# INFO: 	Extracting triples associated to isQualifiedBy
# INFO: 		Time extracting triples for property: 0.13020586967468262 seconds
# INFO: 	Extracting triples associated to isCharacterizedBy
# INFO: 		Time extracting triples for property: 0.1992480754852295 seconds
# INFO: 	Extracting triples associated to qualifies
# INFO: 		Time extracting triples for property: 0.1186063289642334 seconds
# INFO: 	Extracting triples associated to characterizes
# INFO: 		Time extracting triples for property: 0.1289997100830078 seconds
# INFO: 	Extracting triples associated to supersedes
# INFO: 		Time extracting triples for property: 0.13747477531433105 seconds
# INFO: 	Extracting triples associated to hasConstituent
# INFO: 		Time extracting triples for property: 0.18884658813476562 seconds
# INFO: 	Extracting triples associated to isConstituentOf
# INFO: 		Time extracting triples for property: 0.15711259841918945 seconds
# INFO: 	Extracting triples associated to hasDataSource
# INFO: 		Time extracting triples for property: 0.1232748031616211 seconds
# INFO: 	Extracting triples associated to hasDateOfIssuance
# INFO: 		Time extracting triples for property: 0.15891695022583008 seconds
# INFO: 	Extracting triples associated to hasStartDate
# INFO: 		Time extracting triples for property: 0.15392637252807617 seconds
# INFO: 	Extracting triples associated to hasExpirationDate
# INFO: 		Time extracting triples for property: 0.14235901832580566 seconds
# INFO: 	Extracting triples associated to hasEndDate
# INFO: 		Time extracting triples for property: 0.15170526504516602 seconds
# INFO: 	Extracting triples associated to hasRecord
# INFO: 		Time extracting triples for property: 0.12540078163146973 seconds
# INFO: 	Extracting triples associated to hasReportingPeriod
# INFO: 		Time extracting triples for property: 0.12990760803222656 seconds
# INFO: 	Extracting triples associated to hasTerminationDate
# INFO: 		Time extracting triples for property: 0.12432050704956055 seconds
# INFO: 	Extracting triples associated to isAbout
# INFO: 		Time extracting triples for property: 0.13388419151306152 seconds
# INFO: 	Extracting triples associated to records
# INFO: 		Time extracting triples for property: 0.11701345443725586 seconds
# INFO: 	Extracting triples associated to isIndexTo
# INFO: 		Time extracting triples for property: 0.17479825019836426 seconds
# INFO: 	Extracting triples associated to hasBusinessDayAdjustment
# INFO: 		Time extracting triples for property: 0.25626492500305176 seconds
# INFO: 	Extracting triples associated to hasBusinessDayConvention
# INFO: 		Time extracting triples for property: 0.15769600868225098 seconds
# INFO: 	Extracting triples associated to hasBusinessRecurrenceIntervalConvention
# INFO: 		Time extracting triples for property: 0.1796128749847412 seconds
# INFO: 	Extracting triples associated to holdsDuring
# INFO: 		Time extracting triples for property: 0.1806776523590088 seconds
# INFO: 	Extracting triples associated to hasAsOfDate
# INFO: 		Time extracting triples for property: 0.1335146427154541 seconds
# INFO: 	Extracting triples associated to hasCalendarPeriod
# INFO: 		Time extracting triples for property: 0.14681100845336914 seconds
# INFO: 	Extracting triples associated to hasDateAdded
# INFO: 		Time extracting triples for property: 0.13416600227355957 seconds
# INFO: 	Extracting triples associated to hasDateReceived
# INFO: 		Time extracting triples for property: 0.1324467658996582 seconds
# INFO: 	Extracting triples associated to hasDateTime
# INFO: 		Time extracting triples for property: 0.2180643081665039 seconds
# INFO: 	Extracting triples associated to hasFinalStub
# INFO: 		Time extracting triples for property: 0.1575181484222412 seconds
# INFO: 	Extracting triples associated to hasStub
# INFO: 		Time extracting triples for property: 0.1364290714263916 seconds
# INFO: 	Extracting triples associated to hasInitialStub
# INFO: 		Time extracting triples for property: 0.1377878189086914 seconds
# INFO: 	Extracting triples associated to hasOverallPeriod
# INFO: 		Time extracting triples for property: 0.1476755142211914 seconds
# INFO: 	Extracting triples associated to hasRecurrenceInterval
# INFO: 		Time extracting triples for property: 0.14886832237243652 seconds
# INFO: 	Extracting triples associated to hasRecurrenceStartDate
# INFO: 		Time extracting triples for property: 0.13836407661437988 seconds
# INFO: 	Extracting triples associated to hasSchedule
# INFO: 		Time extracting triples for property: 0.1311330795288086 seconds
# INFO: 	Extracting triples associated to hasTimeDirection
# INFO: 		Time extracting triples for property: 0.14691400527954102 seconds
# INFO: 	Extracting triples associated to isRelativeTo
# INFO: 		Time extracting triples for property: 0.14312386512756348 seconds
# INFO: 	Extracting triples associated to exemplifies
# INFO: 		Time extracting triples for property: 0.1568593978881836 seconds
# INFO: 	Extracting triples associated to isExemplifiedBy
# INFO: 		Time extracting triples for property: 0.14064717292785645 seconds
# INFO: 	Extracting triples associated to hasEventDate
# INFO: 		Time extracting triples for property: 0.13425898551940918 seconds
# INFO: 	Extracting triples associated to hasInput
# INFO: 		Time extracting triples for property: 0.12398314476013184 seconds
# INFO: 	Extracting triples associated to isInputTo
# INFO: 		Time extracting triples for property: 0.12055325508117676 seconds
# INFO: 	Extracting triples associated to hasOccurrence
# INFO: 		Time extracting triples for property: 0.18161392211914062 seconds
# INFO: 	Extracting triples associated to hasOutput
# INFO: 		Time extracting triples for property: 0.11710619926452637 seconds
# INFO: 	Extracting triples associated to isOutputFrom
# INFO: 		Time extracting triples for property: 0.1201941967010498 seconds
# INFO: 	Extracting triples associated to isTriggeredBy
# INFO: 		Time extracting triples for property: 0.3706848621368408 seconds
# INFO: 	Extracting triples associated to hasGoal
# INFO: 		Time extracting triples for property: 0.20910286903381348 seconds
# INFO: 	Extracting triples associated to hasObjective
# INFO: 		Time extracting triples for property: 0.28276538848876953 seconds
# INFO: 	Extracting triples associated to hasStrategy
# INFO: 		Time extracting triples for property: 0.1321887969970703 seconds
# INFO: 	Extracting triples associated to appliesIn
# INFO: 		Time extracting triples for property: 0.22377777099609375 seconds
# INFO: 	Extracting triples associated to hasReach
# INFO: 		Time extracting triples for property: 0.15122318267822266 seconds
# INFO: 	Extracting triples associated to hasCapacity
# INFO: 		Time extracting triples for property: 0.13702082633972168 seconds
# INFO: 	Extracting triples associated to isCapacityOf
# INFO: 		Time extracting triples for property: 0.13811922073364258 seconds
# INFO: 	Extracting triples associated to implements
# INFO: 		Time extracting triples for property: 0.14033150672912598 seconds
# INFO: 	Extracting triples associated to involves
# INFO: 		Time extracting triples for property: 0.13269305229187012 seconds
# INFO: 	Extracting triples associated to isImplementedBy
# INFO: 		Time extracting triples for property: 0.1388697624206543 seconds
# INFO: 	Extracting triples associated to implies
# INFO: 		Time extracting triples for property: 0.18337798118591309 seconds
# INFO: 	Extracting triples associated to isImpliedBy
# INFO: 		Time extracting triples for property: 0.15950632095336914 seconds
# INFO: 	Extracting triples associated to isConferredOn
# INFO: 		Time extracting triples for property: 0.18683981895446777 seconds
# INFO: 	Extracting triples associated to isLicensedBy
# INFO: 		Time extracting triples for property: 0.13750839233398438 seconds
# INFO: 	Extracting triples associated to licenses
# INFO: 		Time extracting triples for property: 0.17319631576538086 seconds
# INFO: 	Extracting triples associated to governs
# INFO: 		Time extracting triples for property: 0.18108820915222168 seconds
# INFO: 	Extracting triples associated to hasInForce
# INFO: 		Time extracting triples for property: 0.13468217849731445 seconds
# INFO: 	Extracting triples associated to isInForceIn
# INFO: 		Time extracting triples for property: 0.14842700958251953 seconds
# INFO: 	Extracting triples associated to employs
# INFO: 		Time extracting triples for property: 0.14444565773010254 seconds
# INFO: 	Extracting triples associated to playsActiveRoleThatDirectlyAffects
# INFO: 		Time extracting triples for property: 0.12473821640014648 seconds
# INFO: 	Extracting triples associated to hasEmployedParty
# INFO: 		Time extracting triples for property: 0.17002129554748535 seconds
# INFO: 	Extracting triples associated to hasOrganizationMember
# INFO: 		Time extracting triples for property: 0.16522431373596191 seconds
# INFO: 	Extracting triples associated to isEmployedIn
# INFO: 		Time extracting triples for property: 0.15630483627319336 seconds
# INFO: 	Extracting triples associated to hasEmployee
# INFO: 		Time extracting triples for property: 0.15293574333190918 seconds
# INFO: 	Extracting triples associated to actsOn
# INFO: 		Time extracting triples for property: 0.11949634552001953 seconds
# INFO: 	Extracting triples associated to isEmployeeOf
# INFO: 		Time extracting triples for property: 0.28520917892456055 seconds
# INFO: 	Extracting triples associated to hasEmployingParty
# INFO: 		Time extracting triples for property: 0.15359926223754883 seconds
# INFO: 	Extracting triples associated to hasMembership
# INFO: 		Time extracting triples for property: 0.153151273727417 seconds
# INFO: 	Extracting triples associated to isEmployingParty
# INFO: 		Time extracting triples for property: 0.1546783447265625 seconds
# INFO: 	Extracting triples associated to isDomiciledIn
# INFO: 		Time extracting triples for property: 0.15271449089050293 seconds
# INFO: 	Extracting triples associated to isEmployedBy
# INFO: 		Time extracting triples for property: 0.1418135166168213 seconds
# INFO: 	Extracting triples associated to experiencesDirectly
# INFO: 		Time extracting triples for property: 0.11883401870727539 seconds
# INFO: 	Extracting triples associated to isOrganizationMember
# INFO: 		Time extracting triples for property: 0.1366262435913086 seconds
# INFO: 	Extracting triples associated to isAffectedBy
# INFO: 		Time extracting triples for property: 0.12168431282043457 seconds
# INFO: 	Extracting triples associated to isMembershipPartyIn
# INFO: 		Time extracting triples for property: 0.1338493824005127 seconds
# INFO: 	Extracting triples associated to hasActor
# INFO: 		Time extracting triples for property: 0.15511178970336914 seconds
# INFO: 	Extracting triples associated to hasUndergoer
# INFO: 		Time extracting triples for property: 0.1528174877166748 seconds
# INFO: 	Extracting triples associated to hasSubUnit
# INFO: 		Time extracting triples for property: 0.13688969612121582 seconds
# INFO: 	Extracting triples associated to hasPart
# INFO: 		Time extracting triples for property: 0.15239214897155762 seconds
# INFO: 	Extracting triples associated to isSubUnitOf
# INFO: 		Time extracting triples for property: 0.13619685173034668 seconds
# INFO: 	Extracting triples associated to actsIn
# INFO: 		Time extracting triples for property: 0.14021968841552734 seconds
# INFO: 	Extracting triples associated to undergoes
# INFO: 		Time extracting triples for property: 0.13896679878234863 seconds
# INFO: 	Extracting triples associated to isPartOf
# INFO: 		Time extracting triples for property: 0.14924955368041992 seconds
# INFO: 	Extracting triples associated to hasOwnedAsset
# INFO: 		Time extracting triples for property: 0.15295934677124023 seconds
# INFO: 	Extracting triples associated to isOwnedAsset
# INFO: 		Time extracting triples for property: 0.15680480003356934 seconds
# INFO: 	Extracting triples associated to hasOwningParty
# INFO: 		Time extracting triples for property: 0.15509486198425293 seconds
# INFO: 	Extracting triples associated to isOwningParty
# INFO: 		Time extracting triples for property: 0.15575194358825684 seconds
# INFO: 	Extracting triples associated to isAssetOf
# INFO: 		Time extracting triples for property: 0.15252208709716797 seconds
# INFO: 	Extracting triples associated to ownsAsset
# INFO: 		Time extracting triples for property: 0.15515613555908203 seconds
# INFO: 	Extracting triples associated to isOwnedBy
# INFO: 		Time extracting triples for property: 0.12821340560913086 seconds
# INFO: 	Extracting triples associated to owns
# INFO: 		Time extracting triples for property: 0.12762951850891113 seconds
# INFO: 	Extracting triples associated to directlyAffects
# INFO: 		Time extracting triples for property: 0.22031235694885254 seconds
# INFO: 	Extracting triples associated to experiencesWith
# INFO: 		Time extracting triples for property: 0.11792659759521484 seconds
# INFO: 	Extracting triples associated to isPlayedBy
# INFO: 		Time extracting triples for property: 0.29116129875183105 seconds
# INFO: 	Extracting triples associated to experiences
# INFO: 		Time extracting triples for property: 0.1180107593536377 seconds
# INFO: 	Extracting triples associated to isExperiencedBy
# INFO: 		Time extracting triples for property: 0.12010765075683594 seconds
# INFO: 	Extracting triples associated to playsRole
# INFO: 		Time extracting triples for property: 0.12766575813293457 seconds
# INFO: 	Extracting triples associated to hasActiveParty
# INFO: 		Time extracting triples for property: 0.12305068969726562 seconds
# INFO: 	Extracting triples associated to playsActiveRoleIn
# INFO: 		Time extracting triples for property: 0.11958193778991699 seconds
# INFO: 	Extracting triples associated to hasCommencementDate
# INFO: 		Time extracting triples for property: 0.16675329208374023 seconds
# INFO: 	Extracting triples associated to hasMailingAddress
# INFO: 		Time extracting triples for property: 0.17108726501464844 seconds
# INFO: 	Extracting triples associated to hasParty
# INFO: 		Time extracting triples for property: 0.13235712051391602 seconds
# INFO: 	Extracting triples associated to isAPartyTo
# INFO: 		Time extracting triples for property: 0.18003273010253906 seconds
# INFO: 	Extracting triples associated to hasRelatedPartyInRole
# INFO: 		Time extracting triples for property: 0.1552715301513672 seconds
# INFO: 	Extracting triples associated to hasThingInRole
# INFO: 		Time extracting triples for property: 0.13504385948181152 seconds
# INFO: 	Extracting triples associated to isDirectlyAffectedBy
# INFO: 		Time extracting triples for property: 0.143629789352417 seconds
# INFO: 	Extracting triples associated to playsActiveRoleThatAffects
# INFO: 		Time extracting triples for property: 0.16854381561279297 seconds
# INFO: 	Extracting triples associated to hasIdentity
# INFO: 		Time extracting triples for property: 0.23304986953735352 seconds
# INFO: 	Extracting triples associated to hasIndividualPostcode
# INFO: 		Time extracting triples for property: 0.17290925979614258 seconds
# INFO: 	Extracting triples associated to hasPostdirectionalSymbol
# INFO: 		Time extracting triples for property: 0.1800858974456787 seconds
# INFO: 	Extracting triples associated to hasPredirectionalSymbol
# INFO: 		Time extracting triples for property: 0.1581559181213379 seconds
# INFO: 	Extracting triples associated to hasPrimaryAddressNumber
# INFO: 		Time extracting triples for property: 0.16274333000183105 seconds
# INFO: 	Extracting triples associated to hasSecondaryUnit
# INFO: 		Time extracting triples for property: 0.1642591953277588 seconds
# INFO: 	Extracting triples associated to hasStreetAddress
# INFO: 		Time extracting triples for property: 0.15999102592468262 seconds
# INFO: 	Extracting triples associated to hasStreetName
# INFO: 		Time extracting triples for property: 0.16383647918701172 seconds
# INFO: 	Extracting triples associated to hasStreetSuffix
# INFO: 		Time extracting triples for property: 0.1606888771057129 seconds
# INFO: 	Extracting triples associated to hasStructureName
# INFO: 		Time extracting triples for property: 0.1377887725830078 seconds
# INFO: 	Extracting triples associated to hasTransliteratedAddress
# INFO: 		Time extracting triples for property: 0.3127903938293457 seconds
# INFO: 	Extracting triples associated to hasBusinessCenter
# INFO: 		Time extracting triples for property: 0.18405961990356445 seconds
# INFO: 	Extracting triples associated to hasMunicipality
# INFO: 		Time extracting triples for property: 0.18447327613830566 seconds
# INFO: 	Extracting triples associated to hasCountry
# INFO: 		Time extracting triples for property: 0.15327167510986328 seconds
# INFO: 	Extracting triples associated to hasRegion
# INFO: 		Time extracting triples for property: 0.14711284637451172 seconds
# INFO: 	Extracting triples associated to hasCounty
# INFO: 		Time extracting triples for property: 0.13991951942443848 seconds
# INFO: 	Extracting triples associated to hasSubdivision
# INFO: 		Time extracting triples for property: 0.19266629219055176 seconds
# INFO: 	Extracting triples associated to hasCoverageArea
# INFO: 		Time extracting triples for property: 0.17388439178466797 seconds
# INFO: 	Extracting triples associated to isLocatedAt
# INFO: 		Time extracting triples for property: 0.14812898635864258 seconds
# INFO: 	Extracting triples associated to hasDimension
# INFO: 		Time extracting triples for property: 0.1411428451538086 seconds
# INFO: 	Extracting triples associated to hasFactor
# INFO: 		Time extracting triples for property: 0.17576932907104492 seconds
# INFO: 	Extracting triples associated to hasQuantityKind
# INFO: 		Time extracting triples for property: 0.1720409393310547 seconds
# INFO: 	Extracting triples associated to hasQuantityValue
# INFO: 		Time extracting triples for property: 0.12528514862060547 seconds
# INFO: 	Extracting triples associated to isDerivedFrom
# INFO: 		Time extracting triples for property: 0.15532493591308594 seconds
# INFO: 	Extracting triples associated to specializes
# INFO: 		Time extracting triples for property: 0.15877103805541992 seconds
# INFO: 	Extracting triples associated to appliesTo
# INFO: 		Time extracting triples for property: 0.24848318099975586 seconds
# INFO: 	Extracting triples associated to causes
# INFO: 		Time extracting triples for property: 0.12366127967834473 seconds
# INFO: 	Extracting triples associated to isCausedBy
# INFO: 		Time extracting triples for property: 0.13677644729614258 seconds
# INFO: 	Extracting triples associated to isIncludedIn
# INFO: 		Time extracting triples for property: 0.1392688751220703 seconds
# INFO: 	Extracting triples associated to confers
# INFO: 		Time extracting triples for property: 0.2240619659423828 seconds
# INFO: 	Extracting triples associated to isConferredBy
# INFO: 		Time extracting triples for property: 0.2148725986480713 seconds
# INFO: 	Extracting triples associated to controls
# INFO: 		Time extracting triples for property: 0.11830973625183105 seconds
# INFO: 	Extracting triples associated to isControlledBy
# INFO: 		Time extracting triples for property: 0.11837410926818848 seconds
# INFO: 	Extracting triples associated to defines
# INFO: 		Time extracting triples for property: 0.299915075302124 seconds
# INFO: 	Extracting triples associated to represents
# INFO: 		Time extracting triples for property: 0.11805200576782227 seconds
# INFO: 	Extracting triples associated to isDefinedIn
# INFO: 		Time extracting triples for property: 0.3184378147125244 seconds
# INFO: 	Extracting triples associated to describes
# INFO: 		Time extracting triples for property: 0.21820855140686035 seconds
# INFO: 	Extracting triples associated to isDescribedBy
# INFO: 		Time extracting triples for property: 0.12088561058044434 seconds
# INFO: 	Extracting triples associated to designates
# INFO: 		Time extracting triples for property: 0.1275804042816162 seconds
# INFO: 	Extracting triples associated to isDesignatedBy
# INFO: 		Time extracting triples for property: 0.11999821662902832 seconds
# INFO: 	Extracting triples associated to embodies
# INFO: 		Time extracting triples for property: 0.12015128135681152 seconds
# INFO: 	Extracting triples associated to evaluates
# INFO: 		Time extracting triples for property: 0.11868596076965332 seconds
# INFO: 	Extracting triples associated to isEvaluatedBy
# INFO: 		Time extracting triples for property: 0.1191859245300293 seconds
# INFO: 	Extracting triples associated to exchanges
# INFO: 		Time extracting triples for property: 0.11681151390075684 seconds
# INFO: 	Extracting triples associated to generates
# INFO: 		Time extracting triples for property: 0.11745762825012207 seconds
# INFO: 	Extracting triples associated to isGeneratedBy
# INFO: 		Time extracting triples for property: 0.12532734870910645 seconds
# INFO: 	Extracting triples associated to hasContext
# INFO: 		Time extracting triples for property: 0.13500380516052246 seconds
# INFO: 	Extracting triples associated to hasDesignation
# INFO: 		Time extracting triples for property: 0.13335967063903809 seconds
# INFO: 	Extracting triples associated to hasRepresentation
# INFO: 		Time extracting triples for property: 0.12411212921142578 seconds
# INFO: 	Extracting triples associated to holds
# INFO: 		Time extracting triples for property: 0.13457012176513672 seconds
# INFO: 	Extracting triples associated to isHeldBy
# INFO: 		Time extracting triples for property: 0.117462158203125 seconds
# INFO: 	Extracting triples associated to isIssuedBy
# INFO: 		Time extracting triples for property: 0.13476848602294922 seconds
# INFO: 	Extracting triples associated to isProvidedBy
# INFO: 		Time extracting triples for property: 0.13415098190307617 seconds
# INFO: 	Extracting triples associated to issues
# INFO: 		Time extracting triples for property: 0.1318798065185547 seconds
# INFO: 	Extracting triples associated to isManagedBy
# INFO: 		Time extracting triples for property: 0.11858463287353516 seconds
# INFO: 	Extracting triples associated to manages
# INFO: 		Time extracting triples for property: 0.12831807136535645 seconds
# INFO: 	Extracting triples associated to isMandatedBy
# INFO: 		Time extracting triples for property: 0.1511247158050537 seconds
# INFO: 	Extracting triples associated to mandates
# INFO: 		Time extracting triples for property: 0.12320423126220703 seconds
# INFO: 	Extracting triples associated to isProducedBy
# INFO: 		Time extracting triples for property: 0.11967253684997559 seconds
# INFO: 	Extracting triples associated to produces
# INFO: 		Time extracting triples for property: 0.11782145500183105 seconds
# INFO: 	Extracting triples associated to provides
# INFO: 		Time extracting triples for property: 0.1323390007019043 seconds
# INFO: 	Extracting triples associated to hasAnchorDate
# INFO: 		Time extracting triples for property: 0.13683104515075684 seconds
# INFO: 	Extracting triples associated to hasApplicableDatePeriod
# INFO: 		Time extracting triples for property: 0.13502788543701172 seconds
# INFO: 	Extracting triples associated to hasArgument
# INFO: 		Time extracting triples for property: 0.391329288482666 seconds
# INFO: 	Extracting triples associated to hasExpression
# INFO: 		Time extracting triples for property: 0.14757299423217773 seconds
# INFO: 	Extracting triples associated to hasFixedComparativeDate
# INFO: 		Time extracting triples for property: 0.12183117866516113 seconds
# INFO: 	Extracting triples associated to hasFormula
# INFO: 		Time extracting triples for property: 0.1397418975830078 seconds
# INFO: 	Extracting triples associated to hasMinuend
# INFO: 		Time extracting triples for property: 0.14835405349731445 seconds
# INFO: 	Extracting triples associated to hasObservedValue
# INFO: 		Time extracting triples for property: 0.17499566078186035 seconds
# INFO: 	Extracting triples associated to hasPeriodicity
# INFO: 		Time extracting triples for property: 0.14213252067565918 seconds
# INFO: 	Extracting triples associated to hasReferencePeriod
# INFO: 		Time extracting triples for property: 0.14285516738891602 seconds
# INFO: 	Extracting triples associated to hasRelativeComparativeDate
# INFO: 		Time extracting triples for property: 0.1215054988861084 seconds
# INFO: 	Extracting triples associated to hasRelativeComparativePeriod
# INFO: 		Time extracting triples for property: 0.12208700180053711 seconds
# INFO: 	Extracting triples associated to hasReleaseDate
# INFO: 		Time extracting triples for property: 0.12190723419189453 seconds
# INFO: 	Extracting triples associated to hasSubtrahend
# INFO: 		Time extracting triples for property: 0.14424896240234375 seconds
# INFO: 	Extracting triples associated to isValueOf
# INFO: 		Time extracting triples for property: 0.1445159912109375 seconds
# INFO: 	Extracting triples associated to classifies
# INFO: 		Time extracting triples for property: 0.2171189785003662 seconds
# INFO: 	Extracting triples associated to isClassifiedBy
# INFO: 		Time extracting triples for property: 0.1505568027496338 seconds
# INFO: 	Extracting triples associated to hasSubregion
# INFO: 		Time extracting triples for property: 0.1345233917236328 seconds
# INFO: 	Extracting triples associated to isSubregionOf
# INFO: 		Time extracting triples for property: 0.13498806953430176 seconds
# INFO: 	Extracting triples associated to uses
# INFO: 		Time extracting triples for property: 0.14730000495910645 seconds
# INFO: 	Extracting triples associated to usesAdministrativeLanguage
# INFO: 		Time extracting triples for property: 0.15897130966186523 seconds
# INFO: 	Extracting triples associated to denotes
# INFO: 		Time extracting triples for property: 0.3960878849029541 seconds
# INFO: 	Extracting triples associated to hasDenotation
# INFO: 		Time extracting triples for property: 0.11713647842407227 seconds
# INFO: 	Extracting triples associated to hasEarlierForm
# INFO: 		Time extracting triples for property: 0.13165688514709473 seconds
# INFO: 	Extracting triples associated to hasMember
# INFO: 		Time extracting triples for property: 0.2346668243408203 seconds
# INFO: 	Extracting triples associated to isMemberOf
# INFO: 		Time extracting triples for property: 0.22383809089660645 seconds
# INFO: 	Extracting triples associated to identifies
# INFO: 		Time extracting triples for property: 0.621845006942749 seconds
# INFO: 	Extracting triples associated to isIdentifiedBy
# INFO: 		Time extracting triples for property: 0.19643902778625488 seconds
# INFO: 	Extracting data property assertions
# INFO: 		Time extracting data property assertions: 2.5033297538757324 seconds
# INFO: 	Extracting complex equivalence axioms
# INFO: 		Time extracting complex equivalence axioms: 5.517770767211914 seconds
# INFO: 	Extracting annotations.
# INFO: 		Time extracting annotations: 1.8277692794799805 seconds
# INFO: Projection created into a Graph object (RDFlib library)
# INFO: Projection saved into turtle file: /home/kaishuo/accenture/OWL2Vec-Star/cache/projection.ttl
# Extract classes and individuals ...
#
# Extract axioms ...
#
# Extract annotations ...
#
# Generate URI document ...
# Extracted 6962 walks for 456 seed entities
# Extracted 946 axiom sentences
#
# Generate literal document ...
# Extracted 4 annotation sentences
#
# Generate mixture document ...
# URI_Doc: 7908, Lit_Doc: 7912, Mix_Doc: 7908

# %%
Lit_Doc
# Out:
# [['specification', 'spec'],
#  ['language', 'identifier', 'language', 'symbol'],
#  ['code', 'set', 'coding', 'scheme'],
#  ['statute', 'law', 'statutory', 'law'],
#  ['address', 'component', 'super', 'class', 'of', 'street', 'name', 'label'],
#  ['organizational',
#   'sub-unit',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/ispartof',
#   'organization',
#   'https://spec.edmcouncil.org/fibo/ontology/be/legalentities/formalbusinessorganizations/hasoperatingaddress'],
#  ['code', 'set', 'subclassof', 'scheme', 'label'],
#  ['secondary',
#   'unit',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/comprises',
#   'secondary',
#   'unit',
#   'designator',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin'],
#  ['contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/confers',
#   'legal',
#   'obligation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/jurisdiction/appliesin'],
#  ['duration',
#   'type',
#   'of',
#   'day',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasdurationvalue'],
#  ['industry',
#   'sector',
#   'classification',
#   'scheme',
#   'subclassof',
#   'classification',
#   'scheme',
#   'subclassof'],
#  ['business',
#   'entity',
#   'subclassof',
#   'formal',
#   'organization',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby'],
#  ['monetary', 'price', 'subclassof', 'price', 'label'],
#  ['reference', 'super', 'class', 'of', 'measure', 'super', 'class', 'of'],
#  ['identifier',
#   'super',
#   'class',
#   'of',
#   'language',
#   'identifier',
#   'super',
#   'class',
#   'of'],
#  ['warranty',
#   'subclassof',
#   'contractual',
#   'commitment',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/haspart'],
#  ['employer',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/roles/isplayedby',
#   'legal',
#   'person',
#   'label'],
#  ['religious',
#   'corporation',
#   'subclassof',
#   'not-for-profit',
#   'corporation',
#   'label'],
#  ['spoken',
#   'language',
#   'subclassof',
#   'language',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby'],
#  ['registration',
#   'identifier',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isgovernedby',
#   'jurisdiction',
#   'label'],
#  ['identity',
#   'document',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby',
#   'identifier',
#   'label'],
#  ['address', 'subclassof', 'index', 'label'],
#  ['duty',
#   'super',
#   'class',
#   'of',
#   'legal',
#   'obligation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/ismandatedby'],
#  ['collection', 'super', 'class', 'of', 'ordered', 'collection', 'label'],
#  ['organization', 'name', 'label', 'organization name'],
#  ['legal',
#   'entity',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/isclassifiedby',
#   'industry',
#   'sector',
#   'classifier',
#   'label'],
#  ['occurrence',
#   'kind',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/classifies',
#   'occurrence',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/isclassifiedby'],
#  ['schedule',
#   'stub',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/comprises',
#   'occurrence',
#   'kind',
#   'subclassof'],
#  ['quantity',
#   'kind',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/quantities/quantitiesandunits/hasdimension',
#   'dimensionality',
#   'label'],
#  ['statistical', 'measure', 'label', 'statistical measure'],
#  ['rear', 'type', 'secondary', 'unit', 'designator', 'type', 'of'],
#  ['from', 'the', 'start', 'type', 'time', 'direction', 'type', 'of'],
#  ['quantity',
#   'value',
#   'super',
#   'class',
#   'of',
#   'numeric',
#   'index',
#   'value',
#   'label'],
#  ['collective',
#   'language',
#   'code',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/denotes',
#   'language',
#   'group',
#   'super',
#   'class',
#   'of'],
#  ['regulation',
#   'subclassof',
#   'legal',
#   'construct',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/legalcapacity/isimplementedby'],
#  ['address',
#   'super',
#   'class',
#   'of',
#   'physical',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isdefinedin'],
#  ['organization',
#   'covering',
#   'agreement',
#   'subclassof',
#   'written',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/haseffectivedatetimestamp'],
#  ['monday', 'type', 'time', 'interval', 'super', 'class', 'of'],
#  ['joint', 'stock', 'company', 'label', 'joint stock company'],
#  ['date', 'of', 'death', 'subclassof', 'explicit', 'date', 'label'],
#  ['statistical', 'measure', 'subclassof', 'measure', 'subclassof'],
#  ['street',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/hasstreetsuffix',
#   'street',
#   'suffix',
#   'subclassof'],
#  ['organization',
#   'member',
#   'super',
#   'class',
#   'of',
#   'employee',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/organizations/formalorganizations/isemployeeof'],
#  ['contractual',
#   'definition',
#   'subclassof',
#   'contractual',
#   'element',
#   'label'],
#  ['contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/confers',
#   'legal',
#   'construct',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/legalcapacity/isimplementedby'],
#  ['geographic',
#   'region',
#   'super',
#   'class',
#   'of',
#   'post',
#   'code',
#   'area',
#   'subclassof'],
#  ['contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/hasthirdparty',
#   'contract',
#   'third',
#   'party',
#   'label'],
#  ['death',
#   'certificate',
#   'identification',
#   'scheme',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/defines',
#   'death',
#   'certificate',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['legal',
#   'working',
#   'age',
#   'subclassof',
#   'legal',
#   'age',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/jurisdiction/appliesin'],
#  ['investment', 'objective', 'subclassof', 'financial', 'objective', 'label'],
#  ['bibliographic', 'citation', 'label', 'bibliographic citation'],
#  ['spoken',
#   'language',
#   'subclassof',
#   'language',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasdenotation'],
#  ['federal',
#   'capital',
#   'area',
#   'subclassof',
#   'geopolitical',
#   'entity',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/uses'],
#  ['passport',
#   'number',
#   'identification',
#   'scheme',
#   'subclassof',
#   'identification',
#   'scheme',
#   'subclassof'],
#  ['contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/hascontractparty',
#   'contract',
#   'party',
#   'subclassof'],
#  ['monetary', 'amount', 'super', 'class', 'of', 'income', 'subclassof'],
#  ['unit',
#   'type',
#   'secondary',
#   'unit',
#   'designator',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin'],
#  ['statistical',
#   'universe',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/hascontext',
#   'statistical',
#   'program',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/appliesto'],
#  ['index', 'subclassof', 'reference', 'label'],
#  ['terminology', 'code', 'subclassof', 'alpha-3', 'code', 'subclassof'],
#  ['schedule',
#   'super',
#   'class',
#   'of',
#   'ad',
#   'hoc',
#   'schedule',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/arrangements/arrangements/hasconstituent'],
#  ['agreement',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/parties/haspartyinrole',
#   'party',
#   'in',
#   'role',
#   'label'],
#  ['unit',
#   'of',
#   'account',
#   'identifier',
#   'subclassof',
#   'code',
#   'element',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/ismemberof'],
#  ['maturity', 'level', 'type', 'of', 'informative', 'label'],
#  ['age',
#   'super',
#   'class',
#   'of',
#   'legal',
#   'age',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/jurisdiction/appliesin'],
#  ['tax',
#   'identification',
#   'scheme',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasmember',
#   'tax',
#   'identifier',
#   'subclassof'],
#  ['apartment',
#   'type',
#   'secondary',
#   'unit',
#   'designator',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin'],
#  ['person',
#   'name',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/isstructurednameof',
#   'person',
#   'subclassof'],
#  ['quantity',
#   'kind',
#   'super',
#   'class',
#   'of',
#   'derived',
#   'quantity',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isdefinedin'],
#  ['legally',
#   'competent',
#   'natural',
#   'person',
#   'label',
#   'legally competent natural person'],
#  ['concept', 'scheme', 'hastopconcept', 'concept', 'semanticrelation'],
#  ['identifier',
#   'super',
#   'class',
#   'of',
#   'currency',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['terminology', 'code', 'subclassof', 'language', 'identifier', 'altlabel'],
#  ['national', 'identification', 'number', 'subclassof', 'identifier', 'label'],
#  ['unit', 'factor', 'label', 'unit factor'],
#  ['tax',
#   'identification',
#   'scheme',
#   'subclassof',
#   'identification',
#   'scheme',
#   'subclassof'],
#  ['derived', 'unit', 'label', 'derived unit'],
#  ['region-specific',
#   'identifier',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/isusedby',
#   'geopolitical',
#   'entity',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/uses'],
#  ['thing-in-role', 'super', 'class', 'of', 'licensor', 'label'],
#  ['employer', 'subclassof', 'thing-in-role', 'label'],
#  ['identifier',
#   'super',
#   'class',
#   'of',
#   'death',
#   'certificate',
#   'identifier',
#   'subclassof'],
#  ['contract',
#   'super',
#   'class',
#   'of',
#   'written',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/hasexecutiondatetimestamp'],
#  ['trailer',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/requiressecondaryunitrange',
#   'true'],
#  ['individual',
#   'language',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasdenotation',
#   'individual',
#   'language',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['court', 'of', 'law', 'subclassof', 'formal', 'organization', 'label'],
#  ['tax',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'independent',
#   'party',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/hasaddress'],
#  ['measure',
#   'super',
#   'class',
#   'of',
#   'statistical',
#   'measure',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasapplicabledateperiod'],
#  ['time', 'interval', 'type', 'of', 'monday', 'label'],
#  ['actor',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/parties/actsin',
#   'situation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/parties/hasundergoer'],
#  ['independent',
#   'party',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/hasaddress',
#   'physical',
#   'address',
#   'super',
#   'class',
#   'of'],
#  ['classifier',
#   'super',
#   'class',
#   'of',
#   'supplemental',
#   'address',
#   'designator',
#   'super',
#   'class',
#   'of'],
#  ['contingent',
#   'right',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredon',
#   'independent',
#   'party',
#   'https://spec.edmcouncil.org/fibo/ontology/be/legalentities/formalbusinessorganizations/hasregisteredaddress'],
#  ['objective', 'super', 'class', 'of', 'religious', 'objective', 'subclassof'],
#  ['macrolanguage',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasdenotation',
#   'macrolanguage',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['country',
#   'subdivision',
#   'super',
#   'class',
#   'of',
#   'federal',
#   'state',
#   'subclassof'],
#  ['legal',
#   'obligation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/ismandatedby',
#   'regulation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/confers'],
#  ['identifier', 'subclassof', 'reference', 'super', 'class', 'of'],
#  ['calendar', 'week', 'type', 'calendar', 'period', 'subclassof'],
#  ['thing-in-role',
#   'super',
#   'class',
#   'of',
#   'licensor',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/legalcapacity/licenses'],
#  ['addressing',
#   'scheme',
#   'super',
#   'class',
#   'of',
#   'physical',
#   'addressing',
#   'scheme',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasmember'],
#  ['natural', 'language', 'label', 'natural language'],
#  ['monetary',
#   'amount',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/accounting/currencyamount/hascurrency',
#   'currency',
#   'label'],
#  ['organization',
#   'identifier',
#   'subclassof',
#   'identifier',
#   'super',
#   'class',
#   'of'],
#  ['quantity',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/quantities/quantitiesandunits/hasquantitykind',
#   'quantity',
#   'kind',
#   'label'],
#  ['exchange',
#   'rate',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/accounting/currencyamount/hasbasecurrency',
#   'currency',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/accounting/currencyamount/istenderin'],
#  ['precious',
#   'metal',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby',
#   'precious',
#   'metal',
#   'identifier',
#   'label'],
#  ['written',
#   'contract',
#   'super',
#   'class',
#   'of',
#   'organization',
#   'covering',
#   'agreement',
#   'subclassof'],
#  ['not-for-profit',
#   'corporation',
#   'subclassof',
#   'not',
#   'for',
#   'profit',
#   'organization',
#   'subclassof'],
#  ['country',
#   'subdivision',
#   'subclassof',
#   'geopolitical',
#   'entity',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/uses'],
#  ['autonomous', 'agent', 'label', 'autonomous agent'],
#  ['person',
#   'subclassof',
#   'independent',
#   'party',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/hasaddress'],
#  ['special',
#   'purpose',
#   'language',
#   'concept',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby',
#   'special',
#   'purpose',
#   'code',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['postcode',
#   'subclassof',
#   'geographic',
#   'region',
#   'identifier',
#   'super',
#   'class',
#   'of'],
#  ['employee',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/roles/isplayedby',
#   'person',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/people/hasdateofdeath'],
#  ['exchange', 'rate', 'label', 'exchange rate'],
#  ['objective', 'super', 'class', 'of', 'business', 'objective', 'label'],
#  ['alpha-2',
#   'code',
#   'subclassof',
#   'geographic',
#   'region',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['geographic',
#   'region',
#   'super',
#   'class',
#   'of',
#   'post',
#   'code',
#   'area',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasdenotation'],
#  ['contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/supersedes',
#   'contract',
#   'label'],
#  ['minor',
#   'subclassof',
#   'person',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby'],
#  ['contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/mandates',
#   'contractual',
#   'commitment',
#   'super',
#   'class',
#   'of'],
#  ['formal',
#   'organization',
#   'super',
#   'class',
#   'of',
#   'business',
#   'entity',
#   'label'],
#  ['name',
#   'super',
#   'class',
#   'of',
#   'person',
#   'name',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/isstructurednameof'],
#  ['identification', 'scheme', 'subclassof', 'arrangement', 'label'],
#  ['person',
#   'name',
#   'subclassof',
#   'name',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/isstructurednameof'],
#  ['bibliographic', 'citation', 'subclassof', 'concept', 'topconceptof'],
#  ['owners', "'", 'equity', 'subclassof', 'expression', 'subclassof'],
#  ['language',
#   'identifier',
#   'super',
#   'class',
#   'of',
#   'special',
#   'purpose',
#   'code',
#   'subclassof'],
#  ['business',
#   'strategy',
#   'super',
#   'class',
#   'of',
#   'sales',
#   'strategy',
#   'subclassof'],
#  ['benefit', 'corporation', 'label', 'benefit corporation'],
#  ['profit',
#   'objective',
#   'subclassof',
#   'objective',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasdateperiod'],
#  ['breach',
#   'of',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/appliesto',
#   'contract',
#   'subclassof'],
#  ['quantity',
#   'kind',
#   'factor',
#   'subclassof',
#   'classifier',
#   'super',
#   'class',
#   'of'],
#  ['master',
#   'agreement',
#   'subclassof',
#   'written',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/hasexecutiondatetimestamp'],
#  ['language',
#   'group',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasdenotation',
#   'collective',
#   'language',
#   'code',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/denotes'],
#  ['paid-in', 'capital', 'subclassof', 'owners', "'", 'equity', 'subclassof'],
#  ['macrolanguage',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'macrolanguage',
#   'label'],
#  ['identity',
#   'document',
#   'super',
#   'class',
#   'of',
#   'death',
#   'certificate',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/isevidencefor'],
#  ['legal',
#   'right',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/legalcapacity/implies',
#   'legal',
#   'obligation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredby'],
#  ['independent',
#   'party',
#   'super',
#   'class',
#   'of',
#   'person',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasage'],
#  ['autonomous',
#   'agent',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/ismemberof',
#   'group',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasmember'],
#  ['business', 'day', 'adjustment', 'subclassof', 'convention', 'label'],
#  ['quantity',
#   'kind',
#   'factor',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/quantities/quantitiesandunits/hasquantitykind',
#   'quantity',
#   'kind',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/quantities/quantitiesandunits/hasmeasurementunit'],
#  ['identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/ismemberof',
#   'identification',
#   'scheme',
#   'label'],
#  ['secondary',
#   'unit',
#   'designator',
#   'type',
#   'of',
#   'penthouse',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/requiressecondaryunitrange'],
#  ['secondary', 'unit', 'designator', 'type', 'of', 'penthouse', 'type'],
#  ['code',
#   'element',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin',
#   'composite',
#   'identifier',
#   'subclassof'],
#  ['obligor',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/agreements/hasobligation',
#   'commitment',
#   'label'],
#  ['member-bearing',
#   'organization',
#   'subclassof',
#   'party',
#   'in',
#   'role',
#   'subclassof'],
#  ['formula',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasexpression',
#   'expression',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasargument'],
#  ['jurisdiction', 'label', 'jurisdiction'],
#  ['tuesday', 'type', 'time', 'interval', 'super', 'class', 'of'],
#  ['national',
#   'identification',
#   'number',
#   'scheme',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasmember',
#   'national',
#   'identification',
#   'number',
#   'super',
#   'class',
#   'of'],
#  ['code',
#   'element',
#   'super',
#   'class',
#   'of',
#   'precious',
#   'metal',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['obligee', 'subclassof', 'thing-in-role', 'super', 'class', 'of'],
#  ['system',
#   'of',
#   'quantities',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/isusedby',
#   'system',
#   'of',
#   'quantities',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/uses'],
#  ['right',
#   'super',
#   'class',
#   'of',
#   'contingent',
#   'right',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredon'],
#  ['index', 'super', 'class', 'of', 'physical', 'address', 'label'],
#  ['person',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/hasstructuredname',
#   'person',
#   'name',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/people/hassurname'],
#  ['commitment',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredby',
#   'agreement',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/parties/haspartyinrole'],
#  ['language',
#   'identifier',
#   'super',
#   'class',
#   'of',
#   'terminology',
#   'code',
#   'subclassof'],
#  ['regular',
#   'schedule',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasrecurrenceinterval',
#   'recurrence',
#   'interval',
#   'label'],
#  ['aspect',
#   'super',
#   'class',
#   'of',
#   'explicit',
#   'date',
#   'period',
#   'subclassof'],
#  ['secondary', 'unit', 'designator', 'type', 'of', 'office', 'type'],
#  ['variable',
#   'interest',
#   'entity',
#   'subclassof',
#   'legal',
#   'entity',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/isclassifiedby'],
#  ['party',
#   'in',
#   'role',
#   'super',
#   'class',
#   'of',
#   'contract',
#   'party',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/hasidentity'],
#  ['federal',
#   'capital',
#   'area',
#   'subclassof',
#   'geopolitical',
#   'entity',
#   'super',
#   'class',
#   'of'],
#  ['address',
#   'component',
#   'super',
#   'class',
#   'of',
#   'supplemental',
#   'address',
#   'component',
#   'label'],
#  ['physical',
#   'address',
#   'super',
#   'class',
#   'of',
#   'conventional',
#   'street',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/hasstreetaddress'],
#  ['written',
#   'contract',
#   'super',
#   'class',
#   'of',
#   'master',
#   'agreement',
#   'subclassof'],
#  ['driver',
#   "'s",
#   'license',
#   'subclassof',
#   'identity',
#   'document',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby'],
#  ['driver',
#   "'s",
#   'license',
#   'identifier',
#   'subclassof',
#   'identifier',
#   'label'],
#  ['explicit',
#   'date',
#   'period',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasduration',
#   'explicit',
#   'duration',
#   'label'],
#  ['location', 'label', 'location'],
#  ['mutual',
#   'commitment',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredby',
#   'mutual',
#   'agreement',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/confers'],
#  ['license', 'subclassof', 'legal', 'document', 'label'],
#  ['birth', 'certificate', 'subclassof', 'certificate', 'label'],
#  ['organizational',
#   'sub-unit',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/organizations/organizations/issubunitof',
#   'organization',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby'],
#  ['breach',
#   'of',
#   'covenant',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/appliesto',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/supersedes'],
#  ['license',
#   'super',
#   'class',
#   'of',
#   'business',
#   'license',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/appliesto'],
#  ['expression', 'super', 'class', 'of', 'mean', 'label'],
#  ['jurisdiction',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/jurisdiction/hasreach',
#   'geographic',
#   'region',
#   'super',
#   'class',
#   'of'],
#  ['individual',
#   'language',
#   'identifier',
#   'subclassof',
#   'language',
#   'identifier',
#   'label'],
#  ['specification', 'version', 'is', 'version', 'of', 'specification', 'label'],
#  ['autonomous',
#   'agent',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/hasstructuredname',
#   'name',
#   'label'],
#  ['physical',
#   'address',
#   'identifier',
#   'subclassof',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/ismemberof'],
#  ['organization',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasmember',
#   'independent',
#   'party',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/legalcapacity/hascapacity'],
#  ['national',
#   'identification',
#   'number',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'person',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasage'],
#  ['address',
#   'super',
#   'class',
#   'of',
#   'physical',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/locations/hassubdivision'],
#  ['automated',
#   'system',
#   'subclassof',
#   'autonomous',
#   'agent',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/hasstructuredname'],
#  ['arrangement',
#   'super',
#   'class',
#   'of',
#   'code',
#   'set',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasmember'],
#  ['warranty', 'subclassof', 'contractual', 'commitment', 'subclassof'],
#  ['post',
#   'office',
#   'box',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/comprises',
#   'post',
#   'office',
#   'box',
#   'subclassof'],
#  ['incorporation', 'guarantee', 'subclassof', 'constitution', 'subclassof'],
#  ['region-specific',
#   'identifier',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/isusedby',
#   'geopolitical',
#   'entity',
#   'super',
#   'class',
#   'of'],
#  ['person',
#   'name',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/people/hassurname',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/text',
#   'type'],
#  ['office', 'label', 'office'],
#  ['legal',
#   'capacity',
#   'super',
#   'class',
#   'of',
#   'power',
#   'of',
#   'attorney',
#   'subclassof'],
#  ['situation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/parties/hasactor',
#   'actor',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/parties/actsin'],
#  ['legal', 'age', 'super', 'class', 'of', 'legal', 'working', 'age', 'label'],
#  ['expression', 'super', 'class', 'of', 'ratio', 'subclassof'],
#  ['special',
#   'purpose',
#   'vehicle',
#   'subclassof',
#   'legal',
#   'entity',
#   'https://spec.edmcouncil.org/fibo/ontology/be/legalentities/formalbusinessorganizations/hasequity'],
#  ['geographic',
#   'coordinate',
#   'system',
#   'subclassof',
#   'coordinate',
#   'system',
#   'label'],
#  ['composite',
#   'identifier',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/comprises',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/ismemberof'],
#  ['instrument',
#   'of',
#   'incorporation',
#   'subclassof',
#   'constitution',
#   'subclassof'],
#  ['party-in-role',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'party',
#   'in',
#   'role',
#   'super',
#   'class',
#   'of'],
#  ['physical',
#   'address',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'physical',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/locations/hascountry'],
#  ['signatory',
#   'capacity',
#   'subclassof',
#   'legal',
#   'capacity',
#   'super',
#   'class',
#   'of'],
#  ['term',
#   'sheet',
#   'subclassof',
#   'agreement',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/confers'],
#  ['contract',
#   'party',
#   'super',
#   'class',
#   'of',
#   'contract',
#   'principal',
#   'subclassof'],
#  ['contract', 'super', 'class', 'of', 'unilateral', 'contract', 'label'],
#  ['currency',
#   'basket',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/arrangements/arrangements/hasconstituent',
#   'currency',
#   'label'],
#  ['organization',
#   'identification',
#   'scheme',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasmember',
#   'organization',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/ismemberof'],
#  ['legal',
#   'construct',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredby',
#   'constitution',
#   'label'],
#  ['alpha-3',
#   'code',
#   'subclassof',
#   'geographic',
#   'region',
#   'identifier',
#   'subclassof'],
#  ['alpha-2', 'code', 'subclassof', 'language', 'identifier', 'subclassof'],
#  ['value-added',
#   'tax',
#   'identification',
#   'number',
#   'subclassof',
#   'organization',
#   'identifier',
#   'super',
#   'class',
#   'of'],
#  ['mutual', 'agreement', 'label', 'mutual agreement'],
#  ['scoped',
#   'measure',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasperiodicity',
#   'recurrence',
#   'interval',
#   'super',
#   'class',
#   'of'],
#  ['contractual',
#   'commitment',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/ismandatedby',
#   'contract',
#   'label'],
#  ['country',
#   'subdivision',
#   'subclassof',
#   'geopolitical',
#   'entity',
#   'super',
#   'class',
#   'of'],
#  ['calendar', 'quarter', 'type', 'calendar', 'period', 'label'],
#  ['independent', 'party', 'super', 'class', 'of', 'legal', 'person', 'label'],
#  ['language',
#   'variant',
#   'subclassof',
#   'individual',
#   'language',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby'],
#  ['contractual',
#   'capability',
#   'subclassof',
#   'legal',
#   'capacity',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredby'],
#  ['organization',
#   'part',
#   'identifier',
#   'subclassof',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['quantity',
#   'kind',
#   'factor',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/quantities/quantitiesandunits/hasquantitykind',
#   'quantity',
#   'kind',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/quantities/quantitiesandunits/hasdimension'],
#  ['age',
#   'of',
#   'majority',
#   'subclassof',
#   'legal',
#   'age',
#   'super',
#   'class',
#   'of'],
#  ['addressing',
#   'scheme',
#   'super',
#   'class',
#   'of',
#   'physical',
#   'addressing',
#   'scheme',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/defines'],
#  ['statistical',
#   'area',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/characterizes',
#   'statistical',
#   'population',
#   'label'],
#  ['physical',
#   'address',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby',
#   'physical',
#   'address',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['language',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby',
#   'language',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['geographic',
#   'region',
#   'super',
#   'class',
#   'of',
#   'geopolitical',
#   'entity',
#   'label'],
#  ['corporation', 'subclassof', 'legal', 'entity', 'label'],
#  ['unit',
#   'factor',
#   'subclassof',
#   'classifier',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isdefinedin'],
#  ['system',
#   'of',
#   'units',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/comprises',
#   'system',
#   'of',
#   'units',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin'],
#  ['dispersion',
#   'super',
#   'class',
#   'of',
#   'average',
#   'absolute',
#   'deviation',
#   'label'],
#  ['party-in-role',
#   'identification',
#   'scheme',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/defines',
#   'party-in-role',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['written',
#   'contract',
#   'super',
#   'class',
#   'of',
#   'transferable',
#   'contract',
#   'super',
#   'class',
#   'of'],
#  ['average',
#   'absolute',
#   'deviation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasargument',
#   'mean',
#   'label'],
#  ['identity',
#   'document',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'person',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/roles/playsrole'],
#  ['macrolanguage',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby',
#   'macrolanguage',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['penthouse', 'type', 'secondary', 'unit', 'designator', 'type', 'of'],
#  ['identification',
#   'scheme',
#   'super',
#   'class',
#   'of',
#   'national',
#   'identification',
#   'number',
#   'scheme',
#   'subclassof'],
#  ['stop', 'type', 'secondary', 'unit', 'designator', 'label'],
#  ['undergoer',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/parties/undergoes',
#   'situation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/parties/hasundergoer'],
#  ['language',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasearlierform',
#   'language',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby'],
#  ['language',
#   'variant',
#   'subclassof',
#   'individual',
#   'language',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasdenotation'],
#  ['script',
#   'subclassof',
#   'collection',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/arrangements/arrangements/hasconstituent'],
#  ['duration', 'super', 'class', 'of', 'explicit', 'duration', 'label'],
#  ['legal',
#   'person',
#   'subclassof',
#   'independent',
#   'party',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/hasaddress'],
#  ['schedule',
#   'stub',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/occurrences/hasoccurrence',
#   'occurrence',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/businessdates/holdsduring'],
#  ['structured',
#   'collection',
#   'super',
#   'class',
#   'of',
#   'dated',
#   'structured',
#   'collection',
#   'label'],
#  ['party',
#   'in',
#   'role',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/hasidentity',
#   'independent',
#   'party',
#   'super',
#   'class',
#   'of'],
#  ['breach',
#   'of',
#   'covenant',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/refersto',
#   'contractual',
#   'commitment',
#   'label'],
#  ['address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isdefinedin',
#   'addressing',
#   'scheme',
#   'super',
#   'class',
#   'of'],
#  ['regulation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/mandates',
#   'legal',
#   'obligation',
#   'super',
#   'class',
#   'of'],
#  ['organizational',
#   'sub-unit',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/organizations/organizations/issubunitof',
#   'organization',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasmember'],
#  ['explicit', 'duration', 'type', 'of', 'day', 'type'],
#  ['counterparty', 'subclassof', 'contract', 'party', 'label'],
#  ['special',
#   'purpose',
#   'code',
#   'subclassof',
#   'language',
#   'identifier',
#   'super',
#   'class',
#   'of'],
#  ['collection', 'super', 'class', 'of', 'orthography', 'subclassof'],
#  ['division',
#   'subclassof',
#   'organizational',
#   'sub-unit',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby'],
#  ['owners',
#   "'",
#   'equity',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasargument',
#   'retained',
#   'earnings',
#   'subclassof'],
#  ['derived', 'quantity', 'subclassof', 'quantity', 'kind', 'label'],
#  ['collective',
#   'language',
#   'code',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'language',
#   'group',
#   'subclassof'],
#  ['constant',
#   'subclassof',
#   'reference',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasexpression'],
#  ['geographic',
#   'region',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/issubregionof',
#   'geographic',
#   'region',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/issubregionof'],
#  ['death',
#   'certificate',
#   'identification',
#   'scheme',
#   'subclassof',
#   'identification',
#   'scheme',
#   'label'],
#  ['objective', 'label', 'objective'],
#  ['contractual', 'right', 'label', 'contractual right'],
#  ['certificate', 'super', 'class', 'of', 'death', 'certificate', 'subclassof'],
#  ['agent-in-role', 'subclassof', 'thing-in-role', 'super', 'class', 'of'],
#  ['physical',
#   'address',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'physical',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/locations/hasmunicipality'],
#  ['regulation',
#   'subclassof',
#   'legal',
#   'construct',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredby'],
#  ['quantity',
#   'super',
#   'class',
#   'of',
#   'measurement',
#   'unit',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/quantities/quantitiesandunits/specializes'],
#  ['legal', 'working', 'age', 'subclassof', 'legal', 'age', 'label'],
#  ['coordinate', 'system', 'label', 'coordinate system'],
#  ['classification',
#   'scheme',
#   'super',
#   'class',
#   'of',
#   'system',
#   'of',
#   'units',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/comprises'],
#  ['derived',
#   'quantity',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/quantities/quantitiesandunits/isderivedfrom',
#   'base',
#   'quantity',
#   'subclassof'],
#  ['classifier',
#   'super',
#   'class',
#   'of',
#   'secondary',
#   'unit',
#   'designator',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin'],
#  ['schedule', 'super', 'class', 'of', 'regular', 'schedule', 'subclassof'],
#  ['legal',
#   'document',
#   'super',
#   'class',
#   'of',
#   'license',
#   'super',
#   'class',
#   'of'],
#  ['ratio',
#   'value',
#   'subclassof',
#   'quantity',
#   'value',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/quantities/quantitiesandunits/hasmeasurementunit'],
#  ['regular',
#   'schedule',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/occurrences/hasoccurrence',
#   'occurrence',
#   'label'],
#  ['legal',
#   'construct',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredon',
#   'independent',
#   'party',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/ismemberof'],
#  ['mean', 'subclassof', 'variable', 'subclassof'],
#  ['master',
#   'agreement',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/governs',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/hascontractparty'],
#  ['licensee',
#   'subclassof',
#   'party',
#   'in',
#   'role',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/hasidentity'],
#  ['funds',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/accounting/currencyamount/hascurrency',
#   'currency',
#   'label'],
#  ['common',
#   'interest',
#   'development',
#   'corporation',
#   'subclassof',
#   'not-for-profit',
#   'corporation',
#   'label'],
#  ['age', 'super', 'class', 'of', 'legal', 'age', 'label'],
#  ['date',
#   'period',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasduration',
#   'duration',
#   'subclassof'],
#  ['municipality', 'label', 'municipality'],
#  ['addressing', 'scheme', 'subclassof', 'indexing', 'scheme', 'label'],
#  ['issue',
#   'resolution',
#   'is',
#   'reflected',
#   'in',
#   'specification',
#   'version',
#   'subclassof'],
#  ['name',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/isstructurednameof',
#   'autonomous',
#   'agent',
#   'super',
#   'class',
#   'of'],
#  ['physical',
#   'addressing',
#   'scheme',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/defines',
#   'physical',
#   'address',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['identifier',
#   'super',
#   'class',
#   'of',
#   'death',
#   'certificate',
#   'identifier',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isdefinedin'],
#  ['scheme', 'super', 'class', 'of', 'indexing', 'scheme', 'subclassof'],
#  ['registration',
#   'identifier',
#   'scheme',
#   'subclassof',
#   'organization',
#   'identification',
#   'scheme',
#   'label'],
#  ['organizational',
#   'sub-unit',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/organizations/organizations/issubunitof',
#   'organization',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/ispartof'],
#  ['contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/mandates',
#   'contractual',
#   'commitment',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/haspart'],
#  ['passport', 'number', 'label', 'passport number'],
#  ['stock', 'corporation', 'label', 'stock corporation'],
#  ['organization',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/ispartof',
#   'organization',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/goalsandobjectives/objectives/hasgoal'],
#  ['contingent',
#   'right',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredon',
#   'independent',
#   'party',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/hasstructuredname'],
#  ['system',
#   'of',
#   'units',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/defines',
#   'measurement',
#   'unit',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/quantities/quantitiesandunits/specializes'],
#  ['physical',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/hasstructurename',
#   'structure',
#   'name',
#   'label'],
#  ['dated',
#   'structured',
#   'collection',
#   'subclassof',
#   'collection',
#   'super',
#   'class',
#   'of'],
#  ['reference', 'super', 'class', 'of', 'variable', 'label'],
#  ['party',
#   'in',
#   'role',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby',
#   'party-in-role',
#   'identifier',
#   'subclassof'],
#  ['total', 'subclassof', 'statistical', 'measure', 'label'],
#  ['tax',
#   'identification',
#   'scheme',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasmember',
#   'tax',
#   'identifier',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/jurisdiction/appliesin'],
#  ['legal',
#   'entity',
#   'subclassof',
#   'formal',
#   'organization',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/organizations/formalorganizations/isdomiciledin'],
#  ['time', 'instant', 'super', 'class', 'of', 'date', 'super', 'class', 'of'],
#  ['agent-in-role', 'label', 'agent-in-role'],
#  ['member-bearing',
#   'organization',
#   'subclassof',
#   'party',
#   'in',
#   'role',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/hasidentity'],
#  ['derived',
#   'unit',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/quantities/quantitiesandunits/isderivedfrom',
#   'base',
#   'unit',
#   'label'],
#  ['dated',
#   'collection',
#   'constituent',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasobserveddatetime',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/combineddatetime',
#   'label'],
#  ['collective',
#   'language',
#   'code',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'language',
#   'group',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasdenotation'],
#  ['birth',
#   'certificate',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby',
#   'birth',
#   'certificate',
#   'identifier',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isdefinedin'],
#  ['person',
#   'name',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/isstructurednameof',
#   'person',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/people/hasdateofbirth'],
#  ['time', 'direction', 'type', 'of', 'from', 'the', 'start', 'label'],
#  ['autonomous',
#   'agent',
#   'super',
#   'class',
#   'of',
#   'independent',
#   'party',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/hasstructuredname'],
#  ['https://spec.edmcouncil.org/fibo/ontology/fnd/goalsandobjectives/objectives/program',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/goalsandobjectives/objectives/hasobjective',
#   'objective',
#   'label'],
#  ['organization',
#   'covering',
#   'agreement',
#   'super',
#   'class',
#   'of',
#   'board',
#   'agreement',
#   'subclassof'],
#  ['identification',
#   'scheme',
#   'super',
#   'class',
#   'of',
#   'party-in-role',
#   'identification',
#   'scheme',
#   'label'],
#  ['employee',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/organizations/formalorganizations/isemployeeof',
#   'employer',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/roles/isplayedby'],
#  ['legal',
#   'person',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/roles/playsrole',
#   'employer',
#   'subclassof'],
#  ['contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/hasprincipalparty',
#   'contract',
#   'principal',
#   'label'],
#  ['quantity', 'kind', 'super', 'class', 'of', 'derived', 'quantity', 'label'],
#  ['record', 'subclassof', 'collection', 'label'],
#  ['party', 'in', 'role', 'super', 'class', 'of', 'obligee', 'subclassof'],
#  ['independent',
#   'party',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/ismemberof',
#   'organization',
#   'https://spec.edmcouncil.org/fibo/ontology/be/legalentities/formalbusinessorganizations/hasoperatingaddress'],
#  ['reference', 'super', 'class', 'of', 'name', 'subclassof'],
#  ['date', 'label', 'date'],
#  ['address',
#   'super',
#   'class',
#   'of',
#   'physical',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/isevidencedby'],
#  ['organization', 'label', 'organization'],
#  ['collection', 'super', 'class', 'of', 'currency', 'basket', 'subclassof'],
#  ['postcode', 'subclassof', 'code', 'element', 'super', 'class', 'of'],
#  ['contingent', 'obligation', 'subclassof', 'duty', 'label'],
#  ['national',
#   'identification',
#   'number',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isdefinedin',
#   'national',
#   'identification',
#   'number',
#   'scheme',
#   'subclassof'],
#  ['contractual',
#   'right',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredby',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/haseffectivedate'],
#  ['license',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'license',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isissuedby'],
#  ['space', 'type', 'secondary', 'unit', 'designator', 'subclassof'],
#  ['organization',
#   'name',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/isstructurednameof',
#   'organization',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/goalsandobjectives/objectives/hasgoal'],
#  ['time', 'interval', 'super', 'class', 'of', 'duration', 'subclassof'],
#  ['side', 'type', 'secondary', 'unit', 'designator', 'subclassof'],
#  ['breach',
#   'of',
#   'covenant',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/appliesto',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/hasgoverningjurisdiction'],
#  ['contingent',
#   'obligation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/agreements/isobligationof',
#   'obligor',
#   'label'],
#  ['agreement',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/confers',
#   'commitment',
#   'label'],
#  ['secondary',
#   'unit',
#   'designator',
#   'type',
#   'of',
#   'stop',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/requiressecondaryunitrange'],
#  ['measurement', 'unit', 'subclassof', 'quantity', 'label'],
#  ['supplemental',
#   'address',
#   'component',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/comprises',
#   'supplemental',
#   'address',
#   'designator',
#   'label'],
#  ['secondary', 'unit', 'designator', 'type', 'of', 'stop', 'type'],
#  ['physical', 'address', 'label', 'physical address'],
#  ['weighting', 'function', 'subclassof', 'expression', 'label'],
#  ['organization',
#   'name',
#   'subclassof',
#   'contextual',
#   'name',
#   'super',
#   'class',
#   'of'],
#  ['breach', 'of', 'contract', 'subclassof', 'occurrence', 'kind', 'label'],
#  ['expression',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasargument',
#   'variable',
#   'super',
#   'class',
#   'of'],
#  ['schedule',
#   'super',
#   'class',
#   'of',
#   'regular',
#   'schedule',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/occurrences/hasoccurrence'],
#  ['situation', 'label', 'situation'],
#  ['language',
#   'identifier',
#   'subclassof',
#   'code',
#   'element',
#   'super',
#   'class',
#   'of'],
# ...
#  ['supplemental',
#   'address',
#   'unit',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin',
#   'supplemental',
#   'address',
#   'component',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/comprises'],
#  ['extension',
#   'provision',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/hasextendableperiod',
#   'explicit',
#   'date',
#   'period',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasduration'],
#  ['address',
#   'component',
#   'super',
#   'class',
#   'of',
#   'supplemental',
#   'address',
#   'unit',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin'],
#  ['post',
#   'office',
#   'box',
#   'address',
#   'subclassof',
#   'physical',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/isevidencedby'],
#  ['currency',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'currency',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/accounting/currencyamount/istenderin'],
#  ['obligor',
#   'subclassof',
#   'party',
#   'in',
#   'role',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/parties/hascommencementdate'],
#  ['percentage', 'label', 'percentage'],
#  ['language',
#   'identifier',
#   'super',
#   'class',
#   'of',
#   'bibliographic',
#   'code',
#   'label'],
#  ['language',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/denotes',
#   'language',
#   'super',
#   'class',
#   'of'],
#  ['dispersion',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/appliesto',
#   'finite',
#   'population',
#   'subclassof'],
#  ['statistical',
#   'measure',
#   'super',
#   'class',
#   'of',
#   'dispersion',
#   'subclassof'],
#  ['physical',
#   'address',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'physical',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isdefinedin'],
#  ['unilateral',
#   'commitment',
#   'subclassof',
#   'commitment',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/agreements/isobligationof'],
#  ['power',
#   'of',
#   'attorney',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/haseffectivedate',
#   'date',
#   'subclassof'],
#  ['average',
#   'absolute',
#   'deviation',
#   'subclassof',
#   'dispersion',
#   'subclassof'],
#  ['legal',
#   'obligation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/ismandatedby',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/hascontractduration'],
#  ['geographic',
#   'region',
#   'identifier',
#   'subclassof',
#   'identifier',
#   'subclassof'],
#  ['statistical',
#   'measure',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasapplicabledateperiod',
#   'date',
#   'period',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasenddate'],
#  ['reassignable', 'identifier', 'subclassof', 'identifier', 'subclassof'],
#  ['median',
#   'subclassof',
#   'statistical',
#   'measure',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/ischaracterizedby'],
#  ['identity',
#   'document',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies',
#   'person',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/hasstructuredname'],
#  ['independent',
#   'party',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/hasaddress',
#   'physical',
#   'address',
#   'label'],
#  ['classifier',
#   'super',
#   'class',
#   'of',
#   'supplemental',
#   'address',
#   'designator',
#   'label'],
#  ['standard',
#   'deviation',
#   'super',
#   'class',
#   'of',
#   'annualized',
#   'standard',
#   'deviation',
#   'subclassof'],
#  ['statistical',
#   'program',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/locations/hascoveragearea',
#   'statistical',
#   'area',
#   'label'],
#  ['classification',
#   'scheme',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/defines',
#   'classifier',
#   'super',
#   'class',
#   'of'],
#  ['strategy',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/goalsandobjectives/objectives/hasobjective',
#   'objective',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasdateperiod'],
#  ['classifier',
#   'super',
#   'class',
#   'of',
#   'industry',
#   'sector',
#   'classifier',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/classifies'],
#  ['identifier', 'subclassof', 'reference', 'label'],
#  ['friday', 'type', 'time', 'interval', 'type', 'of'],
#  ['legal',
#   'capacity',
#   'super',
#   'class',
#   'of',
#   'liability',
#   'capacity',
#   'label'],
#  ['board',
#   'agreement',
#   'subclassof',
#   'organization',
#   'covering',
#   'agreement',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/governs'],
#  ['license',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isheldby',
#   'business',
#   'entity',
#   'super',
#   'class',
#   'of'],
#  ['statistical',
#   'population',
#   'subclassof',
#   'statistical',
#   'universe',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/hascontext'],
#  ['breach', 'of', 'covenant', 'label', 'breach of covenant'],
#  ['contract', 'third', 'party', 'label', 'contract third party'],
#  ['postcode', 'subclassof', 'geographic', 'region', 'identifier', 'label'],
#  ['mean', 'subclassof', 'expression', 'super', 'class', 'of'],
#  ['regular',
#   'schedule',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/hasfinalstub',
#   'schedule',
#   'stub',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/occurrences/hasoccurrence'],
#  ['language',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasdenotation',
#   'language',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/denotes'],
#  ['contingent',
#   'right',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredon',
#   'independent',
#   'party',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/ismemberof'],
#  ['identifier', 'super', 'class', 'of', 'language', 'identifier', 'preflabel'],
#  ['statistical', 'measure', 'super', 'class', 'of', 'ratio', 'subclassof'],
#  ['end',
#   'of',
#   'the',
#   'month',
#   'subclassof',
#   'business',
#   'recurrence',
#   'interval',
#   'super',
#   'class',
#   'of'],
#  ['contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/mandates',
#   'contractual',
#   'commitment',
#   'label'],
#  ['alpha-3',
#   'code',
#   'subclassof',
#   'language',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/denotes'],
#  ['statute',
#   'law',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/mandates',
#   'legal',
#   'obligation',
#   'super',
#   'class',
#   'of'],
#  ['street', 'address', 'label', 'street address'],
#  ['contractual',
#   'commitment',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/haspart',
#   'contractual',
#   'commitment',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/ispartof'],
#  ['driver',
#   "'s",
#   'license',
#   'identifier',
#   'subclassof',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['licensor',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/issues',
#   'license',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/confers'],
#  ['total',
#   'subclassof',
#   'expression',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasargument'],
#  ['statistical',
#   'population',
#   'subclassof',
#   'finite',
#   'population',
#   'subclassof'],
#  ['corporation', 'super', 'class', 'of', 'stock', 'corporation', 'subclassof'],
#  ['individual',
#   'language',
#   'identifier',
#   'subclassof',
#   'language',
#   'identifier',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/identifies'],
#  ['unilateral',
#   'contract',
#   'subclassof',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/haseffectivedate'],
#  ['scoped', 'measure', 'subclassof', 'qualified', 'measure', 'subclassof'],
#  ['independent',
#   'party',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/hasaddress',
#   'physical',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/isevidencedby'],
#  ['autonomous',
#   'agent',
#   'super',
#   'class',
#   'of',
#   'independent',
#   'party',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/ismemberof'],
#  ['mutual',
#   'agreement',
#   'subclassof',
#   'agreement',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/confers'],
#  ['party', 'in', 'role', 'super', 'class', 'of', 'obligor', 'label'],
#  ['organization', 'label', 'organization'],
#  ['legal',
#   'document',
#   'super',
#   'class',
#   'of',
#   'contract',
#   'document',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/isevidencefor'],
#  ['member-bearing',
#   'organization',
#   'super',
#   'class',
#   'of',
#   'employer',
#   'subclassof'],
#  ['geographic',
#   'region',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/hassubregion',
#   'geographic',
#   'region',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby'],
#  ['statistical',
#   'measure',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isprovidedby',
#   'statistical',
#   'program',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/provides'],
#  ['relative',
#   'date',
#   'subclassof',
#   'calculated',
#   'date',
#   'super',
#   'class',
#   'of'],
#  ['minor',
#   'subclassof',
#   'person',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/organizations/formalorganizations/isemployedby'],
#  ['address',
#   'super',
#   'class',
#   'of',
#   'physical',
#   'address',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/places/addresses/hasstructurename'],
#  ['duty', 'label', 'duty'],
#  ['front',
#   'type',
#   'secondary',
#   'unit',
#   'designator',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin'],
#  ['independent',
#   'party',
#   'super',
#   'class',
#   'of',
#   'organization',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/haspart'],
#  ['post',
#   'office',
#   'box',
#   'subclassof',
#   'supplemental',
#   'address',
#   'component',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/comprises'],
#  ['schedule',
#   'subclassof',
#   'collection',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/arrangements/arrangements/hasconstituent'],
#  ['reference',
#   'super',
#   'class',
#   'of',
#   'identifier',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin'],
#  ['mutual',
#   'contractual',
#   'agreement',
#   'subclassof',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/haseffectivedate'],
#  ['identification',
#   'scheme',
#   'super',
#   'class',
#   'of',
#   'tax',
#   'identification',
#   'scheme',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/jurisdiction/appliesin'],
#  ['regulation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredby',
#   'law',
#   'super',
#   'class',
#   'of'],
#  ['measure', 'super', 'class', 'of', 'monetary', 'measure', 'subclassof'],
#  ['identifier', 'super', 'class', 'of', 'composite', 'identifier', 'label'],
#  ['geographic',
#   'region',
#   'identifier',
#   'subclassof',
#   'code',
#   'element',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin'],
#  ['https://spec.edmcouncil.org/fibo/ontology/fnd/goalsandobjectives/objectives/program',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/goalsandobjectives/objectives/hasobjective',
#   'objective',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/legalcapacity/isimplementedby'],
#  ['right',
#   'subclassof',
#   'legal',
#   'construct',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isconferredon'],
#  ['calendar', 'period', 'subclassof', 'time', 'interval', 'type', 'of'],
#  ['statistical',
#   'measure',
#   'super',
#   'class',
#   'of',
#   'mean',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasobservedvalue'],
#  ['contractual',
#   'commitment',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/ismandatedby',
#   'contract',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isgovernedby'],
#  ['tuesday', 'type', 'time', 'interval', 'label'],
#  ['national',
#   'identification',
#   'number',
#   'scheme',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasmember',
#   'national',
#   'identification',
#   'number',
#   'label'],
#  ['obligee', 'subclassof', 'thing-in-role', 'label'],
#  ['business',
#   'strategy',
#   'subclassof',
#   'strategy',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/goalsandobjectives/objectives/hasobjective'],
#  ['statute',
#   'law',
#   'subclassof',
#   'law',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/confers'],
#  ['duty',
#   'super',
#   'class',
#   'of',
#   'contingent',
#   'obligation',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/legalcapacity/isimpliedby'],
#  ['non-governmental',
#   'organization',
#   'label',
#   'non-governmental organization'],
#  ['corporation',
#   'subclassof',
#   'legal',
#   'entity',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isgovernedby'],
#  ['geographic',
#   'region',
#   'https://www.omg.org/spec/lcc/countries/countryrepresentation/hassubregion',
#   'geographic',
#   'region',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasdenotation'],
#  ['identity',
#   'document',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agreements/contracts/isevidencefor',
#   'physical',
#   'address',
#   'subclassof'],
#  ['formal',
#   'organization',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/organizations/formalorganizations/isdomiciledin',
#   'geopolitical',
#   'entity',
#   'subclassof'],
#  ['federal',
#   'capital',
#   'area',
#   'subclassof',
#   'geopolitical',
#   'entity',
#   'label'],
#  ['undergoer',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/parties/parties/undergoes',
#   'situation',
#   'super',
#   'class',
#   'of'],
#  ['mean', 'super', 'class', 'of', 'geometric', 'mean', 'subclassof'],
#  ['independent',
#   'party',
#   'subclassof',
#   'autonomous',
#   'agent',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/hasname'],
#  ['wednesday', 'type', 'time', 'interval', 'super', 'class', 'of'],
#  ['alpha-3',
#   'code',
#   'super',
#   'class',
#   'of',
#   'bibliographic',
#   'code',
#   'subclassof'],
#  ['contextual',
#   'name',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/agentsandpeople/agents/isstructurednameof',
#   'independent',
#   'party',
#   'super',
#   'class',
#   'of'],
#  ['legal',
#   'entity',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isgovernedby',
#   'organization',
#   'covering',
#   'agreement',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/governs'],
#  ['numeric',
#   'index',
#   'value',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/utilities/analytics/hasmeasurementdatetime',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/datesandtimes/financialdates/combineddatetime',
#   'label'],
#  ['legal',
#   'entity',
#   'super',
#   'class',
#   'of',
#   'chartered',
#   'legal',
#   'person',
#   'subclassof'],
#  ['person',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/organizations/formalorganizations/isemployedby',
#   'legal',
#   'person',
#   'super',
#   'class',
#   'of'],
#  ['tax',
#   'identifier',
#   'super',
#   'class',
#   'of',
#   'value-added',
#   'tax',
#   'identification',
#   'number',
#   'subclassof'],
#  ['jurisdiction',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/law/jurisdiction/hasreach',
#   'geographic',
#   'region',
#   'label'],
#  ['derived',
#   'quantity',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isdefinedin',
#   'system',
#   'of',
#   'quantities',
#   'https://spec.edmcouncil.org/fibo/ontology/fnd/relations/relations/isincludedin'],
#  ['address',
#   'super',
#   'class',
#   'of',
#   'physical',
#   'address',
#   'https://www.omg.org/spec/lcc/languages/languagerepresentation/isidentifiedby'],
#  ...]
